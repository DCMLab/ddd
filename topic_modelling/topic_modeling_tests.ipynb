# %%
import spacy
from collections import Counter
import tomotopy as tp
import os
from tqdm import tqdm
import pandas
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.manifold import MDS
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import random

# %%
# Remove p.240-end from Hauptmann in "page" folder

# %% [markdown]
# ## Merge paragraphs

# %%
import xml.etree.ElementTree as ET

# %%
ns = { "pcgts" : "http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15" }

# %%
folders = [ 
    'CAP1905',
    'HAU1853',
    'HOS1879',
    'KRA1852',
    'KUN1863',
    'NAU1858',
    'OET1866',
    'RIE1905',
    'THU1877',
    'WEI1860',
    'WEI1861',
]

# %%
paragraphs = []

# %%
for folder in tqdm(folders):
    path = f'../data/{folder}/{folder}/page/'

    for file in os.listdir(path):
        
        tree = ET.parse(path+file)
        root = tree.getroot()
        
        provisory = []

        for region in root.findall(".//pcgts:TextRegion", ns):
            if "{type:paragraph-continued;}" in region.attrib['custom']:          
                texts = region.findall(".//pcgts:TextEquiv", ns)
                paragraph = texts[-1].find(".//pcgts:Unicode", ns).text
                provisory.append(paragraph)
            elif "{type:paragraph;}" in region.attrib['custom']:
                texts = region.findall(".//pcgts:TextEquiv", ns)
                paragraph = texts[-1].find(".//pcgts:Unicode", ns).text
                if provisory:
                    newpar = ""
                    for i in range(len(provisory)):
                        newpar += provisory[i] + " "
                    newpar += paragraph
                    provisory = []
                    paragraphs.append(newpar)
                else:
                    paragraphs.append(paragraph)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:06<00:00,  1.70it/s]

# %%
len(paragraphs)
# Out:
# 1814

# %% [markdown]
# ## Load data

# %%
# Load german model
#nlp = spacy.load('de_core_news_lg')
nlp = spacy.load('de_dep_news_trf')

# %%
custom_stopwords =  ['B.', '$', 'Fig', 'z.', 'MATH', '=', "S.", "Seite", "2c", "GRAPHIC", "pag", "NB", "C.",
                    "s.", "u.", "v.", "k", "l", "i", "R.", "H.", "de", "F.", "d.", "h.", "c.", "J.", "a.", "M.",
                    "enthalten",
                    "vgl.",
                    "blos",
                    "nämlich",
                    "lassen",
                    "bringen",
                    "geben",
                    "finden",
                    "namentlich",
                    "meist",
                    "stellen",
                    "halten",
                    "nunmehr",
                    "mithin",
                    "sogar",
                    "gar",
                    "stets",
                    "et",
                    "la",
                   ] + [str(i) for i in range(1000)]

# %%
for c in custom_stopwords:
    nlp.vocab[c].is_stop = True
    
# explicitly include words in vocab 
for c in ["a"]:
    nlp.vocab[c].is_stop = False

# %%
lemmatizer = nlp.get_pipe("lemmatizer")

# %%
# Parse files
file_list = []
for file in os.listdir('../data/all_txt/'):
    file_list.append(file)
    
print(file_list)
# Out:
# ['CAP1905.txt', 'HAU1853.txt', 'HOS1879.txt', 'KRA1852.txt', 'KUN1863.txt', 'NAU1858.txt', 'OET1866.txt', 'RIE1905.txt', 'THU1877.txt', 'WEI1860.txt', 'WEI1861.txt']

# %%
# Create a dictionary of all lemmatized texts
texts = dict()
for file in tqdm(file_list):
    with open(f'../data/all_txt/{file}', 'r', encoding='utf-8') as f:
        text = f.read()
        text = text.replace('¬\n', '')
        doc = nlp(text)
        name = file.split('.')[0]
        
        texts[name] = doc
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [04:12<00:00, 22.92s/it]

# %% [markdown]
# ## Book-level topic modeling

# %%
mdl_b = tp.LDAModel(k=5)

# %%
for name, txt in texts.items():
    words = [token.text
         for token in txt
         if not token.is_stop and not token.is_punct and not token.is_space]
    mdl_b.add_doc(words)

# %%
mdl_b.train(2000)

# %%
mdl_b.save('bookmodel.bin', full=False)

# %% [markdown]
# ## 100-word-level topic modeling

# %%
mdl_100 = tp.LDAModel(k=5)

# %%
for txt in texts.values():
    words = [token.text
         for token in txt
         if not token.is_stop and not token.is_punct and not token.is_space]
    for i in range(0,len(words),100):
        mdl_100.add_doc(words[i: i+100])

# %%
mdl_100.train(2000)

# %%
mdl_100.save("100model.bin", full=False)

# %% [markdown]
# ## Paragraph-level topic modeling

# %%
# Clean paragraphs
clean_pars = []
for par in tqdm(paragraphs):
    newpar = par.replace('¬\n', '')
    doc = nlp(newpar)
    clean_pars.append(doc)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1814/1814 [12:28<00:00,  2.42it/s]

# %%
mdl_p = tp.LDAModel(k=5)

# %%
for par in clean_pars:
    words = [token.lemma_
         for token in par
         if not token.is_stop and not token.is_punct and not token.is_space]
    mdl_p.add_doc(words)

# %%
mdl_p.train(2000)

# %%
mdl_p.save("parmodeltrf2.bin", full=False)

# %% [markdown]
# ## Chapter-level topic modeling

# %%
mdl_c = tp.LDAModel(k=5)

# %% [markdown]
# ### pyLDAvis

# %%
import warnings
import pyLDAvis
# Out:
# C:\Users\cmetrai2\anaconda3\envs\doc\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    #pyLDAvis.save_html(prepared_data, "ldavis.html")
    
    pyLDAvis.enable_notebook()
# Out:
# C:\Users\cmetrai2\anaconda3\envs\doc\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mdl = mdl_b

topic_term_dists = np.stack([mdl.get_topic_word_dist(k) for k in range(mdl.k)])
doc_topic_dists = np.stack([doc.get_topic_dist() for doc in mdl.docs])
doc_lengths = np.array([len(doc.words) for doc in mdl.docs])
vocab = list(mdl.used_vocabs)
term_frequency = mdl.used_vocab_freq

prepared_data = pyLDAvis.prepare(
    topic_term_dists,
    doc_topic_dists,
    doc_lengths,
    vocab,
    term_frequency,
    sort_topics=False,
    start_index=1,
)
pyLDAvis.save_html(prepared_data, "bookldavis.html")
pyLDAvis.display(prepared_data)
# Out:
# C:\Users\cmetrai2\anaconda3\envs\doc\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2032022452429333208850429335"></div>
# <script type="text/javascript">
#
# var ldavis_el2032022452429333208850429335_data = {"mdsDat": {"x": [0.3214197707542737, -0.21791490249009887, -0.11623934162322071, -0.1086498448287236, 0.12138431818776955], "y": [-0.16122138777813724, -0.2739065102101159, 0.10418307572053676, 0.15619379300470154, 0.17475102926301483], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [10.643556429821347, 26.717091699730993, 24.174344438606592, 17.758359034113973, 20.706648397727097]}, "tinfo": {"Term": ["c", "g", "+", "e", "f", "d", "a", "Quint", "Tonart", "C", "Bestimmung", "Grundton", "Accorde", "tonischen", "Riemann", "Musik", "c+", "b", "Einheit", "phonischen", "Moll", "enthalten", "Fortschreitung", "h", "phon", "Verwandtschaft", "Tonika", "Accord", "musikalischen", "Klang", "Riemann", "Tonika", "Konsonanz", "Akustik", "Akkord", "Prim", "Dualismus", "vgl.", "Stumpf", "g\u2032", "H\u00f6ren", "Mollklang", "Skala", "Mollakkord", "Oktave", "Riemanns", "Akkorde", "Doppelklang", "Mollklanges", "Phonika", "Problemschrift", "Grundbass", "Durakkord", "bezw", "Verschmelzung", "e\u2032", "Mod", "d\u2032", "Kombinationst\u00f6ne", "physikalischen", "Moll", "Dur", "Obert\u00f6ne", "verstanden", "C", "e", "g", "c", "a", "Auffassung", "h", "d", "Oettingen", "Grundton", "G", "f", "geh\u00f6rt", "Sinne", "F", "Terz", "Unterdominante", "Ton", "Klang", "musikalische", "c+", "einzelnen", "g+", "f+", "Consonanz", "Partialt\u00f6ne", "Schwebungen", "scheint", "III", "gr", "Intervallen", "Terzen", "V", "Kl\u00e4ngen", "sagen", "genau", "etc.", "consonanten", "offenbar", "bekanntlich", "Schritt", "kl", "Leipzig", "vertreten", "folgt", "geltend", "Princip", "Aufl\u00f6sungen", "That", "Beziehungen", "w.", "musikalischen", "Musik", "Intervalle", "Art", "Klang", "A.", "reinen", "Dissonanz", "Octave", "harmonischen", "zweier", "Aufl\u00f6sung", "Theorie", "Verwandtschaft", "T\u00f6ne", "verschiedene", "Quinte", "Sexte", "Terz", "Reihe", "Intervall", "Weise", "unmittelbar", "Kl\u00e4nge", "Ton", "verschiedenen", "Bestimmung", "Fortschreitung", "Metrum", "Glied", "C-e-G", "metrischen", "Uebergang", "metrische", "Momente", "Formation", "metrisch", "geschehen", "H\u00e4lfte", "Octav", "K\u00fcrze", "Bezug", "Anfang", "Mitte", "Accent", "Oberdominantseite", "Gliederung", "C-Durtonart", "hervorgehen", "Zweiheit", "Unterdominantseite", "Gliedes", "Oberdominant", "vierzeitigen", "Vermittlung", "dreizeitigen", "Quint", "Einheit", "enthalten", "Dreiklange", "Ordnung", "Grundtone", "enth\u00e4lt", "Folge", "Bedeutung", "Septimenaccorde", "Dreiklanges", "Terz", "Verbindung", "Grundton", "tonischen", "G", "lassen", "D", "F", "Tonart", "bestimmt", "Bestimmungen", "Form", "Dreiklang", "a", "C", "Ton", "Septime", "h", "Beispiele", "Verfasser", "alten", "Harmoniesystem", "Tonkunst", "Weitzmann", "Vorhalte", "Beispielen", "\u00e4lteren", "gebracht", "neueren", "dur-", "Aufgabe", "Terze", "G.", "As", "Harmonien", "Verz\u00f6gerung", "Herr", "\u00fcberm\u00e4\u00dfige", "\u00fcberm\u00e4\u00dfigen", "C-dur", "frei", "freilich", "Abhandlung", "Quintenparallelen", "theils", "Gebrauch", "l\u00e4ngst", "Auftreten", "bringen", "Zusammenkl\u00e4nge", "Tonart", "chromatischen", "ebenfalls", "Tonarten", "Erkl\u00e4rung", "auftreten", "l\u00e4\u00dft", "fast", "folgenden", "Harmonielehre", "unten", "Quinten", "Harmonieen", "Dreiklang", "geben", "Accorde", "T\u00f6ne", "C", "dur", "lassen", "Stimmen", "T\u00f6nen", "Quinte", "verminderten", "finden", "Dreikl\u00e4nge", "Accord", "Harmonie", "erscheinen", "Ton", "phonischen", "phon", "Bestandtheile", "ton", "phonische", "Bestandtheil", "Phonica", "Scala", "l.", "aufsteigenden", "sub", "Gebilde", "Element", "d0", "g7", "tonisch", "absteigenden", "vorliegenden", "phonisch", "Systemen", "-c", "la", "Tabelle", "Schema", "Bestandtheilen", "antinomen", "Geschlecht", "Tonfolge", "analog", "glaube", "+", "f", "c", "d", "g", "b", "Modulation", "Leiter", "e", "Systeme", "Gegensatz", "i.", "Beziehung", "a", "Melodie", "Helmholtz", "as", "Accord", "Accorde", "Hauptmann", "Ton", ...

# %%
mdl = mdl_100

topic_term_dists = np.stack([mdl.get_topic_word_dist(k) for k in range(mdl.k)])
doc_topic_dists = np.stack([doc.get_topic_dist() for doc in mdl.docs])
doc_lengths = np.array([len(doc.words) for doc in mdl.docs])
vocab = list(mdl.used_vocabs)
term_frequency = mdl.used_vocab_freq

prepared_data = pyLDAvis.prepare(
    topic_term_dists,
    doc_topic_dists,
    doc_lengths,
    vocab,
    term_frequency,
    sort_topics=False,
    start_index=1,
)
pyLDAvis.save_html(prepared_data, "100ldavis.html")
pyLDAvis.display(prepared_data)
# Out:
# C:\Users\cmetrai2\anaconda3\envs\doc\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2032022452429334481794671985"></div>
# <script type="text/javascript">
#
# var ldavis_el2032022452429334481794671985_data = {"mdsDat": {"x": [0.2867514207621317, -0.2360333389015939, -0.11949730211074061, 0.1940618645154782, -0.1252826442652757], "y": [0.2400406455131162, -0.030008207573754962, -0.04153886804014908, -0.31936680734301276, 0.15087323744380068], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [9.938928048179168, 18.767168014360557, 27.85657678259169, 16.949506750311464, 26.487820404557116]}, "tinfo": {"Term": ["c", "e", "g", "Accorde", "a", "f", "d", "h", "+", "T\u00f6ne", "Quint", "C", "Accord", "Aufl\u00f6sung", "Kl\u00e4nge", "Bestimmung", "G", "Folge", "Ton", "Einheit", "Grundton", "b", "Riemann", "Verwandtschaft", "Musik", "Septime", "c+", "Accordes", "Moll", "Ordnung", "Riemann", "Tonika", "Konsonanz", "Akkord", "Prim", "Dualismus", "vgl.", "Stumpf", "Mollklang", "g\u2032", "H\u00f6ren", "Mollakkord", "Riemanns", "Oktave", "Akkorde", "Mollklanges", "Phonika", "Problemschrift", "Durakkord", "Klavier", "bezw", "Verschmelzung", "Mod", "e\u2032", "Kombinationst\u00f6ne", "\u266e", "Verh\u00e4ltnis", "Zalen", "0e", "Skalen", "Doppelklang", "Moll", "Dur", "Akustik", "Obert\u00f6ne", "Unterdominante", "verstanden", "C", "Auffassung", "g", "Oettingen", "c", "e", "Sinne", "sogar", "a", "Sexte", "Erkl\u00e4rung", "Klang", "Umkehrung", "dur", "Bestimmung", "Ordnung", "Metrum", "Glied", "C-e-G", "metrischen", "metrische", "Momente", "Formation", "metrisch", "Glieder", "H\u00e4lfte", "Octav", "K\u00fcrze", "Accent", "C-Durtonart", "Oberdominantseite", "Gliederung", "hervorgehen", "Gliedes", "Unterdominantseite", "Oberdominant", "vierzeitigen", "Vermittlung", "dreizeitigen", "D|F-a", "Paare", "Gliede", "h-D|F", "Metrums", "Einheit", "Quint", "Zweiheit", "Grundtone", "Uebergang", "Dreiklange", "enthalten", "Form", "Folge", "Fortschreitung", "enth\u00e4lt", "Bestimmungen", "lassen", "Bedeutung", "Terz", "Moment", "Verbindung", "l\u00e4sst", "Septimenaccorde", "tonischen", "Dreiklang", "Grundton", "Reihe", "erhalten", "Dissonanz", "Kl\u00e4nge", "c+", "phonischen", "phon", "Schwingungszahlen", "Stimmung", "blos", "ton", "g+", "f+", "phonische", "giebt", "Partialt\u00f6ne", "Schwebungen", "Klangfolge", "w.", "Deutung", "Temperatur", "l.", "Tonh\u00f6he", "Intervallen", "d+", "Kl\u00e4ngen", "Schwingungen", "Klangbedeutung", "genau", "etc.", "sub", "Gebilde", "Consonanzen", "Helmholtz", "Verwandtschaft", "System", "Klang", "Intervalle", "Zahlen", "Octave", "reinen", "Systeme", "T\u00f6ne", "einzelnen", "Klanges", "unmittelbar", "Weise", "Dissonanz", "Reihe", "Art", "Musik", "Ton", "Terz", "harmonischen", "Intervall", "Quinte", "Bedeutung", "Verfasser", "Harmoniesystem", "Tonkunst", "Musiker", "Weitzmann", "Schrift", "Leipzig", "Beethoven", "\u00e4lteren", "Tonsystem", "theoretischen", "gebracht", "Werke", "Zweck", "Marx", "neueren", "Mangel", "G.", "Harmonien", "Herr", "Verz\u00f6gerung", "C-dur", "Abhandlung", "Quintenparallelen", "Theoretiker", "Gebrauch", "aufgestellt", "neuere", "praktische", "Resultate", "Harmonieen", "Lehre", "alten", "la", "Aufgabe", "bringen", "Theorie", "Harmonik", "Harmonielehre", "Melodie", "Musik", "Beispiele", "Anwendung", "erkl\u00e4ren", "Vorhalte", "musikalischen", "geben", "Harmonie", "lassen", "Erkl\u00e4rung", "namentlich", "Dissonanzen", "musikalische", "Begr\u00fcndung", "Tonart", "Tonarten", "finden", "Accorde", "f", "d", "h", "+", "Accord", "Aufl\u00f6sung", "G", "Accordes", "as", "fis", "Stufe", "Bestandtheile", "gis", "Stimme", "Accorden", "chromatischen", "Leiter", "verminderte", "chromatische", "Bestandtheil", "B", "Septimenaccordes", "dissonirenden", "Leitton", "Scala", "melodisch", "liegen", "abw\u00e4rts", "Stufen", "melodische", "a", "b", "c", "e", "Septime", "g", "D", "C", "Grundton", "Ton", "T\u00f6ne", "F", "Tonart", "Quinte", "Dreiklang", "Dreikl\u00e4nge", "Beziehung", "Folge", "Terz", "tonischen"], "Freq": [989.0, 669.0, 637.0, 494.0, 626.0, 474.0, 473.0, 450.0, 425.0, 869.0, 377.0, 474.0, 344.0, 326.0, 294.0, 216.0, 259.0, 494.0,  ...

# %%
import pyLDAvis
import numpy as np 
import warnings

mdl = mdl_p

topic_term_dists = np.stack([mdl.get_topic_word_dist(k) for k in range(mdl.k)])
doc_topic_dists = np.stack([doc.get_topic_dist() for doc in mdl.docs])
doc_lengths = np.array([len(doc.words) for doc in mdl.docs])
vocab = list(mdl.used_vocabs)
term_frequency = mdl.used_vocab_freq

prepared_data = pyLDAvis.prepare(
    topic_term_dists,
    doc_topic_dists,
    doc_lengths,
    vocab,
    term_frequency,
    sort_topics=False,
    start_index=1,
)
pyLDAvis.save_html(prepared_data, "paragraphtrfldavis.html")
pyLDAvis.display(prepared_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e70550f0c043> in <module>
#       3 import warnings
#       4
# ----> 5 mdl = mdl_p
#       6
#       7 topic_term_dists = np.stack([mdl.get_topic_word_dist(k) for k in range(mdl.k)])
#
# NameError: name 'mdl_p' is not defined
