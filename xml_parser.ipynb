# %%
from lxml import etree
import re
import json
import pandas
from collections import Counter

# %%
nsmap = {"": "http://www.tei-c.org/ns/1.0"}

# %%
path = 'Riemann1880.xml'

# %%
tree = etree.parse(path).getroot()

# %%
#number of pages
page = tree.findall(".//pb", nsmap)
len(page)
# Out:
# 98

# %% [markdown]
# ## Extract plain text

# %%
def extract_text(element):
    if element.text:
        yield re.sub(r'\ +', ' ', element.text)
    for child in element.getchildren():
        yield from extract_text(child)
    if element.tail:
        yield re.sub(r'\ +', ' ', element.tail)

# %%
body = tree.findall(".//body", nsmap)

# %%
print(''.join(extract_text(body[0])))
# Out:
#  SKIZZE EINER NEUEN METHODE
#  DER
#  HARMONIELEHRE.
#  VON
#  DR. HUGO RIEMANN
#  LEIPZIG,
#  DRUCK UND VERLAG VON BREITKOPF UND HÄRTEL
#  1880.
#  HERRN ABBÉ
#  DR. FRANZ LISZT
#  VEREHRUNGSVOLL ZUGEEIGNET.
#  Da meine »Musikalische Syntaxis«, zufolge der com¬
#  VORWORT.
#  Da sich dieses Schriftchen nicht an solche wen¬
#  det, welche die Harmonielehre erlernen wollen, sondern
#  vielmehr an die Lehrer selbst oder doch an solche,
#  welche die Lehre bereits inne haben, so setzt es nicht
#  allein die Kenntniss der Intervalle und Accorde, über¬
#  haupt der Terminologie der Generalbasslehre, sondern
#  auch der wichtigsten Thatsachen der Akustik, beson¬
#  ders der Phänomene der Obertöne und des Mittönens
#  voraus. Sein Zweck ist, die neuesten Fortschritte der
#  Wissenschaft in der Erkenntniss der natürlichen Grund¬
#  lagen der Harmonielehre für die Praxis zu verwerthen
#  und die einer früheren Periode entstammende Gene¬
#  ralbasslehre, welche nur in sehr beschränktem Masse
#  von diesen Fortschritten Gewinn zu ziehen geeignet
#  ist, durch eine gänzlich neue Methode des Unterrichts
#  zu ersetzen.
#  Die überraschend einfachen Resultate, welche diese
#  neue Methode ergiebt, sowie der fortwährende Zusam¬
#  menhang mit den grundlegenden wissenschaftlichen
#  Thatsachen, der auch noch in den kleinsten Details
#  hervortritt, werden die beste Empfehlung sowohl für
#  die praktische Brauchbarkeit als für die Consequenz
#  des Systems sein.
#  Da meine »Musikalische Syntaxis«, zufolge der com¬
#  plicirten Terminologie, nicht gemeinverständlich und für
#  die Praxis überhaupt nicht berechnet ist, meine »Neue
#  Schule der Harmonik« und »Musikalische Grammatik
#  aber leider ihres grossen Umfanges und des buchhänd¬
#  VI
#  Vorwort.
#  lerischen Risikos wegen noch immer des Verlegers
#  harren, so mache ich mit dieser kleinen Schrift den
#  Versuch, mit dem Schlussresultate jener Bücher, der
#  Probe für die Praxis zuerst hervorzutreten, um
#  damit dem System selbst Freunde zu gewinnen.
#  Keineswegs verhehle ich mir die Schwierigkeiten,
#  welche sich jeder Neugestaltung der Harmonie-Lehrme¬
#  thode entgegenstellen; dass aber eine solche Neugestal¬
#  tung eine Frage unserer Zeit ist, scheint mir zweifellos
#  festzustehen. Für jene frühere Zeit, welche im Accord
#  nur ein zufälliges Zusammentreffen mehrerer Stimmen sah,
#  war die Generalbassschrift die einzig mögliche Art der
#  Accordbezifferung; heute, wo die Lehre von den Klängen
#  und der Klangvertretung Gemeingut geworden ist, dür¬
#  fen wir auch nach einer Bezifferung verlangen, welche
#  die Klangbedeutung der Accorde erkennen lässt.
#  Möge man in diesen Vorschlägen nichts anderes
#  sehen als einen Versuch, wie deren voraussichtlich noch
#  mehr gemacht werden, bis endlich der rechte kommt,
#  der allgemeine Anerkennung findet. Mit gutem Ge¬
#  wissen darf ich behaupten, dass meine Vorschläge
#  nicht der Neuerungssucht entsprungen sind; dieselben
#  sind vielmehr das Resultat andauernden Bestrebens,
#  die Theorie und Praxis in Einklang zu erhalten und
#  alles heranzuziehen, was den Harmonieschüler am
#  schnellsten über die harmonische Struktur musika¬
#  lischer Werke aufklären kann. Möge man sie so auf-
#  fassen und nicht als ketzerisch ungeprüft verwerfen.
#  Bromberg, 1880.
#  Dr. Hugo Riemann.
#  —
#  Kap. I.
#  II.
#  III.
#  IV.
#  V.
#  VI.
#  Inhalt.
#  a
#  Seite
#  Consonante Accorde
#  „ „ „ „ I — 6
#  §§ 1. Klänge. 2. Octavtöne. 3. Bezifferung.
#  Folgen consonanter Accorde
#  6 — 18
#  §§ 4. Vierstimmiger Accordsatz. 5. Harmoniefolge.
#  6. Stimmführung. 7. Mollsatz. 8. Der Seitenwech-
#  sel. 9. Gegenquintschritte. 10. Der Ganztonschritt.
#  11. Der Quintwechsel. 12. Der Gegenquintwechsel.
#  13. Tonart.
#  Die Nebenklänge der Tonart
#  19 — 28
#  ** * * * * *
#  §§ 14. Der Terzwechsel. 15. Der Kleinterzwechsel.
#  16. Der Leittonwechsel. 17. Der Ganztonwechsel.
#  18. Der Tritonuswechsel. 19. Der Terzschritt. 20. Der
#  Kleinterzschritt. 21. Der Leittonschritt.
#  Septimenaccorde und Sextaccorde. 28 — 38
#  §§ 22. Natürliche Septimenaccorde. 23. Verminderter
#  Dreiklang. 24. Die Sextaccorde. 25. Grosse Septi-
#  menaccorde.
#  Nonenaecorde. Verminderter Septimenaccord.
#  38 — 43
#  §§ 26. Grosse Nonenaccorde. 27. Kleine Nonenaccorde
#  Übermässiger Dreiklang. Alterirte Accorde. Sche¬
#  — 57
#  44
#  matisirung der Dissonanzen
#  *
#  §§ 28. Übermässiger Dreiklang. Kleine Sextaccorde.
#  29. Alterirte Accorde. 30. Schematisirung der Dis¬
#  sonanzen.
#  Inhalt.
#  VIII
#  Kap. VII. Vorhaltsdissonanzen.
#   * * * * * * *
#  §§ 31. Quartenvorhalt. 32. Secundvorhalt. 33. Sex-
#  ten- und Septimenvorhalte. 34. Vorhalte im Sep-
#  timenaccorde. 35. Vorhalte im übermässigen Sext-
#  accorde, kleinen Nonenaccorde und Terznonen-
#  accorde. 36. Quartsextaccord.
#  VIII.
#  Tonalitat
#  §§ 37. Tonleiter und Tonart. 38. Systematik der
#  Harmonieschritte. 39. Enharmonische Verwechse¬
#  lung. 40. Direct verständliche Harmonieschritte.
#  41. Modulation. 42. Tonartenverwandtschaft.
#  43. Freie Übungen.
#  Aufgaben:
#  Seite 8. 10. 12. 14. 16. 18. 20. 25. 27. 33. 35. 37.
#  43. 51. 57. 63.
#  Seite
#  57 — 67
#  67 — 92
#  I.
#  Consonante Accorde.
#  1. Klänge. Es giebt nur zwei Arten consonanter Accorde,
#  nämlich Duraccorde und Mollaccorde. Ein Duraccord
#  besteht aus einem Haupttone, seiner Oberquint und
#  Oberterz, ein Mollaccord aus Hauptton, Unterquint und
#  Unterterz; diese drei Töne: Hauptton, Quintton und
#  Terzton sind die wesentlichen Bestandtheile jedes consonanten
#  Accordes, doch können nur Oberquint und Oberterz, oder Unter¬
#  quint; und Unterterz mit dem Haupttone zusammen einen con¬
#  sonanten Accord bilden, nicht aber Oberquint und Unterterz
#  oder Unterquint und Oberterz, eine Verbindung letzterer Art
#  ergiebt vielmehr immer einen dissonanten Accord. Nennen
#  wir die Verbindung von Hauptton, Oberterz und Oberquint
#  statt Duraccord: Oberklang, und die von Hauptton, Unter¬
#  terz und Unterquint statt Mollaccord: Unterklang, so kön¬
#  nen wir sagen: Oberklang und Unterklang widersprechen ein¬
#  ander, verschmelzen nicht zur Einheit, auch wenn der Haupt¬
#  ton derselbe ist; ihre Verbindung ist so gut ein Doppelklang,
#  eine Klangzweiheit, wie die Verbindung von Klängen, die
#  nicht denselben Hauptton haben.
#  2. Octavtöne. Töne, welche im Verhältniss der Octave
#  zu einander stehen, sind ihrer Harmoniebedeutung nach nicht
#  verschiedene Töne, sondern Wiederholungen desselben Tones
#  in verschiedener Höhenlage, und werden daher auch in un¬
#  serem Musiksystem gleich benannt, z. B. C: c, e: e' u. s. w.
#  Es verändert deshalb die Harmoniebedeutung eines Dur- oder
#  Moll-Accordes ganz und gar nicht, wenn der Hauptton oder
#  der Quintton oder der Terzton oder zwei derselben oder alle in
#  die höhere oder die tiefere Octave versetzt oder in höheren oder
#  tieferen Octaven wiederholt (verdoppelt) werden. Allerdings
#  wird dadurch der Klang (die Klangfarbe) verändert, aber nicht
#  2
#  I. Consonante Accorde.
#  die harmonische Bedeutung: die Consonanz bleibt ungestört.
#  Folgende Accorde sind daher sämmtlich gleichbedeutend, näm¬
#  lich als c-Oberklang:
#  1.
#
#  Dass es für die Stimmführung, für die Accordverbindung, für
#
#  die Logik der Harmonieverkettungen nicht einerlei ist, ob der
#  Klang in dieser oder jener Gestalt erscheint, steht allerdings
#  fest; das erste, die Hauptsache ist aber, dass wir in allen die¬
#  sen Fällen einen und denselben Klang vor uns haben, der nur
#  jedesmal anders dargestellt, anders vertreten ist.
#  3. Bezifferung. Um alle die Accorde unter 1 wie ebenso
#  die unter 2 in einer Weise bezeichnen zu können, welche so¬
#  fort die Identität ihrer Harmoniebedeutung augenfällig macht,
#  bedürfen wir eines Zeichens für den Klang. In neuerer Zeit
#  ist es sehr gebräuchlich, sich dafür der Tonbuchstaben zu be¬
#  dienen, d. h. man bezeichnet den c-Duraccord mit einem
#  grossen C den c-Mollaccord mit einem kleinen c; da indess
#  die Unterscheidung der grossen Buchstaben von den kleinen
#  zugleich auch für die verschiedenen Octavlagen (gross C, klein c,
#  eingestrichen c' etc.) üblich ist, so ziehen wir es vor, durch
#  einen Zusatz zum Tonbuchstaben anzudeuten, ob dessen Ober¬
#  klang oder Unterklang gemeint ist und zwar wählen wir die
#  bereits von einem bedeutenden Theoretiker*) gebrauchten: + für
#  Oberklang und 0 für Unterklang, d. h. c+ ist der c-Oberklang
#  *) A. v. Öttingen, Harmoniesystem in dualer Entwickelung (1866).
#  1 Klänge. 2. Octavtöne. 3. Bezifferung.
#  (c-Duraccord), ’0cc-Unterklang (f-Mollaccord).
#  Wollen wir andeuten, welcher Accordton (Hauptton, Quintton
#  oder Terzton) in der Oberstimme oder Bassstimme ist, so be¬
#  dienen wir uns dafür der Zahlen 1 (= Hauptton), 3 (= Terz)
#  und 5 (= Quint) und zwar für den Oberklang dieser arabi¬
#  schen Ziffern, so dass 3 die Oberterz und 5 die Oberquint
#  betleutet, für den Unterklang dagegen der römischen Zah¬
#  len I (Hauptton) III (Unterterz) V (Unterquint). Die Gene¬
#  ralbassbezifferung ist an eine notirte Bassstimme gebunden,
#  mag diese in Noten oder in Buchstaben gegeben sein; die hier
#  zu entwickelnde dagegen ist ebensogut bei gegebener Mittel¬
#  oder Oberstimme zu verwenden, ja es braucht gar keine Stim¬
#  me gegeben zu sein, die Harmonie kann jederzeit unzwei¬
#  felhaft chiffrirt werden. c+ bedeutet nun also den c-Duraccord,
#  c3 (das Kreuzchen ist überflüssig, sobald eine arabische Zahl
#  dabei steht, da diese nur fur einen Ton des Duraccordes
#  zur Anwendung kommt) ist die zweite Lage des c-Duraccor¬
#  des (nach Generalbassterminologie der Sextaccord) c5 die dritte
#  Lage (Gen. Bass: Quartsextaccord), c1, c3, e5 dagegen fordern
#  den Hauptton, die Terz oder die Quinte für die Oberstimme.
#  Ebenaso verständlich sind die Doppelbezeichnungen c13355333
#  etc. Ist eine Stimme in Noten gegeben, so werden wir, wenn
#  c se.bst die zu beziffernde Note ist, den c-Duraccord einfach
#  durch + verlangen, oder wenn durch eine Zahl bestimmt wer¬
#  den soll, welcher Ton in die Ober- oder Unterstimme soll, so
#  genügt die blosse Zahl mit einem Strich über sich (für die
#  Oberstimme) oder unter sich (Unterstimme):
#  Hier ist bei a) der c-Oberklang gefordert ohne nähere Bestim¬
#  mung der Lage, bei b) soll die Terz in die Oberstimme, bei
#  c) soll die Terz in die Unterstimme, bei d) soll die Terz in
#  die Unterstimme und die Quint in die Oberstimme.
#  Ist c gegeben und der Mollaccord unter c (c-Unterklang)
#  wird verlangt, so geschieht das einfach durch 0 (vergl. 4 a),
#  I. Consonante Accorde.
#  4
#  ein übergeschriebenes III fordert die Terz für die Oberstimme
#  (4 b), ein III fordert die Terz fur die Unterstimme (4 c),
#  V
#  fordert die Terz fur die Unterstimme und die Quint
#  ein
#  III
#  für die Oberstimme (4 d).
#  a) 0 b) III
#  d) III
#  c) III
#  —
#
#
#
#
#  —
#  4.
#
#
#
#
#
#  E
#
#
#  S.
#  Ist nicht der Hauptton gegeben, sondern die Quint oder Terz,
#  so muss der Klang jederzeit durch den Buchstaben gefordert
#  werden z. B.
#  III
#  1
#  c
#
#  90 0c c
#  c
#  e
#  —
#
#
#
#  —
#
#
#
#
#
#
#  .
#  —
#  +
#  5.
#
#  —
#
#  —
#
#  Nehmen wir nun z. B. eine der ersten Aufgaben des Richter-
#  schen Lehrbuches der Harmonie und versehen sie statt mit
#  der Generalbassbezifferung mit der hier entwickelten, die ich
#  Klangschlüssel nennen will, so sieht das vergleichsweise
#  so aus :
#  No. 70. 3.)
#  (Richter.
#  6 6
#  6
#  6
#  2
#  —
#
#
#  Generalbass.
#
#
#
#  —
#  —
#
#
#  —
#  1.
#  +
#  *
#  6.
#
#
#
#  Klangschlüssel
#
#
#
#
#  —
#  —
#  Scheinbar ist die letztere Bezifferung viel complicirter als die
#  alte. Es liegt das daran, dass die Generalbezifferung durch
#  den Mangel jedes Zeichens über dem Tone den Dreiklang for-
#  dert, wie ihn gerade die Tonleiter nach den Vorzeichen er¬
#  giebt; wir können einen Theil dieser Abkürzung acceptiren,
#  indem wir durch den Mangel jedes Zeichens andeuten, dass
#  der Oberklang (Duraccord) der gegebenen Noten gemeint
#  ist, und auch beim Buchstaben das * weglassen. Dann sieht
#  obiges Beispiel schon viel einfacher aus:
#  3. Bezifferung.
#  5
#  c a de 9a
#  c
#  c
#  —
#  ——
#
#
#  6 b.
#  +
#  —
#  —
#  —
#
#
#
#
#
#  —
#  —
#  Indess ist das gar nicht von Belang. Die Vortheile, welche
#  die neue Bezifferung bietet, sind schon bis jetzt grösser als die
#  Nachtheile; denn dieselbe ist nicht an die Bassstimme gebun¬
#  den. Denken wir uns für obiges Beispiel die Melodiestimme
#  gegeben, so muss der Generalbass wenn er nicht über einer
#  besonders notirten Bassstimme stehen soll, immer die Buch¬
#  staben zu Hülfe nehmen, z. B.
#  ——
#
#
#  7.
#
#
#
#  +
#  6 6
#  6
#  6
#  3
#  Gen. B.
#
#  /
#  e
#  e
#  e 9 f g a f
#  5
#  9
#  Dann sind wir, wenn wir die Nichtbezeichnung
#  für den Dur¬
#  accord beibehalten, bereits im Vortheil:
#
#  7b.
#
#
#
#
#
#
#
#
#  I.
#  e g
#   9 0
#  a 9
#  ef
#  9
#  III
#  Einen weiten Vorsprung vor der Generalbassbezifferung
#  gewinnen wir, sobald viele nicht leitereigene Accorde vorkom¬
#  men, d. h. Versetzungszeichen nöthig werden; z. B. würde
#  folgendes Beispiel:
#  15
#  2
#
#  —
#
#  8.
#
#  2—
#
#
#
#
#
#
#
#
#
#  im Klangschlüssel notirt so aussehen
#  0e
#
#
#  8b.
#
#
#
#
#
#  —
#  I
#
#  gegebener Oberstimme:
#  oder bei
#  —
#
#  +
#  —
#
#
#
#
#
#  .—
#  —
#
#  9.
#
#  —
#  25
#  Gen. B. 4 k a à g
#
#  9b.
#  0
#  c de K
#  9
#  6
#  II. Folgen consonanter Accorde.
#  Der Hauptvorzug des Klangschlüssels liegt aber
#  darin, dass er jederzeit das Verwandtschaftsver-
#  hältniss der einander direct folgenden Klänge so¬
#  fort erkennen lässt und dadurch den Schüler, wenn
#  er nach der im folgenden vorgezeichneten Methode
#  die Regeln des Satzes erlernt hat, in den Stand setzt,
#  sofort zu übersehen, mit was für Schwierigkeiten
#  er zu kämpfen hat.
#  II.
#  Folgen consonanter Accorde.
#  4. Vierstimmiger Accordsatz. Den beginnenden Accord
#  soll der Schüler zunächst immer in einer schlussfähigen
#  Gestalt aussetzen, d. h. den Duraccord mit dem Haupt¬
#  tone als Basston, den Mollaccord (Unterklang) mit
#  der Unterquinte als Basston. Dabei sind ferner noch
#  folgende Regeln zu beobachten, die allgemeine Gültigkeit auch
#  für den Verfolg haben:
#  1) Die beiden Mittelstimmen sollen niemals eine Octave
#  von einander entfernt sein; die Oberstimme darf einzelne Male,
#  besonders bei der Gipfelnote der Melodie, eine Octave von der
#  Altstimme abstehen, aber nicht weiter.
#  2) Der Umfang von F bis a“ soll nicht überschritten
#  werden.
#  3) Der Hauptton darf verdoppelt, ja verdreifacht werden,
#  die Quinte darf auch verdoppelt werden, die Terz nicht (Aus¬
#  nahmen ergeben sich später).
#  4) Die Quinte des Duraccordes darf ausgelassen werden,
#  die Terz nicht; im Mollaccord darf der Mollhauptton ausge¬
#  lassen werden, doch nur, wenn die Quinte Basston ist.*
#  *) Die natürliche Erklärung dieser eigenthümlichen Satzregel ist, dass
#  die Quinte des Duraccordes als dritter Oberton, auch wenn sie nicht ange¬
#  geben wird, stark hörbar ist; ebenso ist der Mollhauptton als dritter Ober-
#  ton des Mollquinttones stark zu hören. Wichtig ist nur, dass diese den
#  ausgelassenen Ton als Oberton mit sich führenden Töne im Bass liegen,
#  weil dann der dritte Oberton in den Accord hinein fällt.
#  4. Vierstimmiger Accordsatz. 5. Harmoniefolge.
#  7
#  5. Harmoniefolge. Um dem Schüler mit Leichtigkeit
#  gelzufig zu machen, bei welchen Harmoniefolgen er besondere
#  Gefahren (Quintenparallelen, übermässiger Secundschritt, Tri-
#  tonus etc.) zu vermeiden hat, ist es vortheilhaft, wenn er die
#  verschiedenen möglichen Harmonieschritte systematisch kennen
#  lernt, von den einfacheren, leicht verständlichen, zu den schwe¬
#  rerr. fortschreitend. Da die bisher übliche Terminologie: Ac-
#  cord der dritten Stufe der Durtonart — Accord der fünften
#  Stufe der Paralleltonart etc. zu schwerfällig und nicht einmal
#  völlig ausreichend ist, so schlage ich eine nahe liegende ein¬
#  fachere vor. Wir betrachten nämlich die einander
#  folgenden Klänge immer nach dem Verwandt¬
#  schaftsverhältniss der Haupttöne und unterscheiden
#  danach zunächst Quintschritte, Terzschritte etc. Die am
#  leichtesten verständliche Harmoniefolge ist die Folge der Ober-
#  dominante auf die Tonika der Durtonart z. B. c*—
#  9; in
#  Ansehung des Intervalls der Haupttöne ist der Schritt ein
#  Quintschritt, und da die Quinte, zu der fortgeschritten
#  wird (g), die dem ersten Klange (c'’) angehörige ist, so wollen
#  wir den Schritt
#  den schlichten Quintschritt
#  nennen. Geschieht derselbe Schritt zurück zum Ausgangs-
#  klange, so nennen wir ihn Dominantschritt und zeichnen ihn
#  durch besondere Benennung vor allen anderen zurückgesche¬
#  henden Schritten aus. Bekanntlich ist dieser Schritt der be-
#  liebteste, durchaus überwiegende Schlussschritt.
#  6. Stimmführung. Die ersten Übungen im vierstim-
#  migen Satze müssen nun zunächst in Dur am schlichten
#  Quintschritt (c“ g*) und Dominantschritt (g'c) ge¬
#  macht werden.
#  Dabei sind folgende Regeln zu beobachten:
#  1)
#  Der gemeinsame Ton bleibt liegen.
#  2)
#  Die übrigen Stimmen machen womöglich Secundschritte.
#  3)
#  Besondere Aufmerksamkeit ist dem möglichen klei¬
#  nen Secundschritte (Leittonschritte) zu schenken.
#  4) Der Bass macht Secundschritte oder schreitet von
#  Hauptton zu Hauptton fort.
#  II. Folgen consonanter Accorde.
#  5) Octavenparallelen sind fehlerhaft,
#  weil die Selb-
#  ständigkeit der Stimmen aufhebend.
#  So sind nun reguläre Fortschreitungen:
#
#  ——
#
#
#  —
#
#
#
#  —
#  neh
#
#  10.
#
#
#  —
#  32
#
#  ——
#  —
#  —
#  —
#  S.
#
#
#
#
#
#
#  fehlerhafte dagegen z. B.
#
#
#
#  G
#  ——
#
#  11.
#
#
#  —
#
#
#  Es ist beim schlichten Quintschritt und seiner Umkeh¬
#  rung (dem Dominantschritt) schwer, Fehler zu machen. Da¬
#  durch darf sich aber der Lehrer nicht verleiten lassen, schnell
#  über denselben hinwegzugehen; er darf nicht vergessen, dass,
#  was ihm selbstverständlich ist, dem Schüler erst geläufig wer-
#  den muss. Es ist deshalb rathsam, diese Gelegenheit zu be¬
#  nutzen, um den Schüler auch in den Tonarten mit vielen Vor¬
#  zeichen heimisch zu machen, damit er überall die schlichten
#  Quintschritte und Dominantschritte sofort wieder erkenne.
#  Die folgenden Aufgaben dürften deshalb erheblich ver-
#  mehrt werden.
#  (Sopran gegeben.)
#  b)
#
#
#
#
#
#
#  12.
#
#
#
#
#  c 9
#  3
#  3 9
#  7
#  3 fe J
#  /
#  9
#  d)
#  +
#  h-
#  —
#
#
#
#
#  .
#
#  —t
#  —
#  a
#  d a d
#  des as des as
#  as
#  (Bass gegeben.)
#  *)
#  pe)
#
#  —
#
#
#
#
#
#
#
#
#  L
#
#  3 fis h
#  h fis
#  as es
#  6. Stimmführung.
#  7. Mollsatz.
#  9
#  NB. Über die Bezifferung dieser Beispiele ist noch einiges Ergänzende
#  zu bemerken. In den ersten Beispielen, wo die gegebene Stimme Sopran
#  ist, steht mehrmal die 3 ohne Strich; es kann aber kein Zweifel sein, dass
#  dami; der Terzton für den Bass verlangt ist. Die Striche sind nur nö¬
#  thig, wenn entweder mehrere Zahlen zugleich vorgeschrieben sind (nämlich
#  wenn später auch 2, 4, 6, 7 beim Klange vorkommen), oder beim einfachen
#  Klange, wenn eine Mittelstimme (Alt oder Tenor) gegeben, und kein Buch-
#  stabe übergeschrieben, also der Hauptton als Note gegeben ist. Die
#  Pünktchen“ im 4. Takte des ersten Beispiels bedeuten das Bleiben der-
#  selbeit Harmonie; es ist also nicht der Hauptton des e-Duraccordes, son¬
#  dern des vorausgegangenen c-Duraccordes gefordert (vergl. auch Beispiel i).
#  Übungen mit dem schlichten Quintschritt und Dominant¬
#  7. Mollsatz. Der schlichte Quintschritt zwischen Moll¬
#  accorden (Unterklängen) geschieht eine Quinte ab¬
#  wärts, da der Quintton des Mollaccordes die Unter-
#  quinte des Haupttones ist. Der Dominantschritt in Moll
#  ist daher der Schritt von der Unterdommante zur Tonika, der-
#  selbe hat ebenso wie der Schritt von der Oberdominante zur
#  Tonika in Dur besondere Schlusskraft. Dass der geeignetste
#  Bassion des Mollaccordes (für eine schlussfähige Gestalt) die
#  Quinte ist, muss immer hervorgehoben werden. Im übrigen
#  bleiben die Regeln genau dieselben wie beim Dursatz:
#  Bindung des gemeinsamen Tones, Secundschritte, Leitton¬
#  schritte, — Octavenverbot, die Fortschreitung des Basses ge-
#  schieht aber hier natürlich vorzugsweise von Quintton zu Quint-
#  ton, denn Grundton ist c sogut in c:e:gwie in c:es:g
#  man darf Grundton und Hauptton durchaus nicht für gleich-
#  —
#  bedeutend halten (es ist das eine Anschauung, die in der Ge¬
#  neralbasslehre wurzelt).
#  Übungen mit dem schlichten Quintschritt und Dominant¬
#  schritt zwischen Unterklängen mögen sein (beliebig zu vermehren):
#  10
#  13.
#  II. Folgen consonanter Accorde.
#  (Sopran.)
#  b) *)
#  a)
#  —
#
#
#
#
#
#
#  □
#
#  —
#
#  k de 0 e 0 %e k
#  0 da 0 a 1 . 08 0
#  V—
#  V
#  III
#  (Alt.) c)
#  0
#  —
#
#  E
#  ——.—
#
#  —2
#  —
#
#
#  0
#  a Od IIo00d 0
#  9
#  d III à
#  III I III V
#  (Tenor.)
#  1)
#
#
#
#
#  S
#  LE
#
#
#
#
#
#
#
#  —
#  05
#  0 Oes 0 des 95 es
#  Deis Ofis Ocis fes
#  0 Ofis Ocis
#  III
#  III
#  h)
#  (Bass.) g)
#
#  n
#  —
#
#
#  n
#  —
#
#
#  2
#
#
#  -
#
#  tt
#
#
#
#
#
#  Oes Oas 0 Oas Oes das des
#  Odis Ogis Odisogis 0 Ogisdis
#  8. Der Seitenwechsel. Der Oberklang und Unterklang
#  desselben Tones sind allerdings Gegensätze, ihr Zusammen-
#  klang ist Dissonanz, aber ihre Folge ist gerade, weil sie ein¬
#  ander direct entgegengesetzt sind, desto besser verständlich.
#  Wir wollen diese Folge, bei der dem Klange der obern Seite
#  der der untern folgt (oder umgekehrt) »Seitenwechselc nennen
#  z. B. cf— %c oder %e — et. Die Rückkehr vom Seitenwech-
#  selklange zum Ausgangsklange hat wie der Dominantschritt
#  Schlussbedeutung. Für den Satz bietet der Seitenwechsel kei-
#  nerlei Schwierigkeiten; statt eines Leittonschrittes bie¬
#  tet er Gelegenheit, zwei zu machen:
#
#
#
#  14.
#  Snti
#
#
#
#  1
#
#
#  Der Bass geht
#  gewöhlich vom Durhauptton zur Mollquinte
#  oder umgekehrt,
#  oder macht Secundfortschreitungen:
#  *) In diesem Beispiele bleibt der Basston durchweg derselbe, wie durch
#  die Bindung der V des ersten und letzten Accordes angedeutet ist: diese
#  Bezeichnungsweise wird für den Orgelpunkt bei gegebener Oberstimme
#  unentbehrlich.
#  8. Der Seitenwechsel. 9. Gegenquintschritte.
#  11
#  Der Übergang von der Terz des einen Klanges zur Terz des
#  anderen ergiebt einen Stimmenschritt, den der Schüler vor¬
#  läufig gänzlich zu meiden hat, nämlich die übermässige
#  Quinte (as — e') oder verminderte Quarte (as — e); letz¬
#  tere ist besser als erstere und kann in der Melodie mit gutem
#  Effect vorkommen:
#  9. Gegenquintschritte. Eine ähnliche Bedeutung wie
#  der Seitenwechsel hat der Schritt von einem Duraccorde nach
#  dem Duraccorde der Unterquinte (Unterdominante) oder von
#  einem Mollaccorde nach dem Mollaccorde der Oberquinte
#  z. B. —fr, de — h. Vorausgesetzt wir fassen den c-Dur¬
#  accord als Hauptklang, als Tonika auf, d. h. wir befinden
#  uns in c-Dur, so ist f ein ähnlicher Gegensatz gegen e' wie
#  der Seitenwechselklang ’c; ebenso ist % von ähnlicher ge-
#  gensätzlicher Wirkung gegen 'e, wenn letzteres Tonika ist.
#  Der Satz des Gegenquintschritts, wie wir ihn darum
#  nennei wollen, weil er nicht zu der dem Ausgangsklange an-
#  gehörigen Quinte, sondern nach der entgegengesetzten geschieht,
#  ist derselbe wie der des schlichten Quintschrittes, oder viel¬
#  mehr seiner Umkehrung, des Dominantschrittes, nur ist bei
#  ihm der Leittonschritt nicht von gleicher Wichtigkeit, da er
#  nicht zurückleitende, sondern vorwärtsschreitende Bedeutung
#  hat (bei er—f
#  = e —f). Beim Rückgange vom Gegen-
#  quintklange zur Tonika (Plagalschluss) gewinnt dagegen bei
#  f* —
#  e der Stimmschritt f e (fallender (Moll- Leitton¬
#  schritt, eine ähnliche Bedeutung wie sie beim Dominantschritt
#  g— e* der Schritt h — c (steigender Dur- Leittonschritt)
#  12
#  II. Folgen consonanter Accorde.
#  hat, und ist ihm deshalb Gewicht beizulegen. Entsprechend
#  kommt beim umgekehrten (retrograden) Gegenquintschritt in
#  Moll (% — %e) der steigende Leittonschritt h — c zur Gel-
#  tung, während beim Moll-Dominantschritt ’a — %e der eigent¬
#  liche Mollleittonschritt/—
#  e den Schluss besonders wirksam
#  macht.
#  Die nun folgenden Aufgaben verbinden mit der Tonika den
#  schlichten Quintklang, Gegenquintklang und Seitenwechsel¬
#  klang, bieten aber sonst keinerlei neue Schwierigkeiten dar:
#  17. (Sopran.)
#  a)
#  NB.
#  b)
#  NB.
#
#
#
#  c
#  c
#
#  9
#  c
#  Fb53 J.
#  (Alt.)
#  NB.
#  d
#  NB.
#  NB.
#
#
#
#
#  —
#
#  —
#
#
#  +
#  +
#
#  e
#  e h
#
#  5
#  a 5h e
#  h 68
#  5
#  3
#  5
#  (Tenor.)
#
#  2
#  e)
#  NB.
#
#
#
#
#
#
#
#  7-5—
#
#  —
#  —
#
#  —
#
#
#
#
#
#  —
#
#  +0 3 es 70 5 es
#  0 Ceis
#  gis gis Vgis gis Ogis
#  HI 5
#  (Bass.)
#  NB.
#  8)
#  h)
#
#  ——
#  —
#
#
#  E
#
#
#
#
#
#  —
#
#
#  Oh kr sis Oh hßs
#  9ßs fier Ofts % 0 0 0•+ 0
#  (Sopran.)
#  k)
#
#  —
#  ——
#
#
#  0% 0 02 0 % 0
#  6e 0½ 06 6 0 02 0
#  (Bass.)
#  1)
#  m)
#
#
#
#
#  T
#
#
#
#  +
#  —
#
#
#
#
#  0 % a 0 0 0
#  Ocis Ofis Ocis Ogis Ocis %ßs Scis
#  NB. Wiederholt kommt in obigen Beispielen der Duraccord mit der
#  Quinte als Basston vor (was wir Quintlage nennen wollen — der HGene¬
#  ralbass versteht bekanntlich unter Quintlage die Quint als Ton der Ober-
#  stimme); ohne uns vorläufig über die Bedeutung dieses Accordes auszu¬
#  10. Der Ganztonschritt.
#  13
#  zulassen (wir werden ihn unter den Dissonanzen wiederfinden), müssen wir
#  doch hier für den Satz den Fingerzeig geben, dass in den Fällen, wo
#  die Quinte im folgenden Accorde Hauptton wird (e—g*) nicht
#  der Hauptton des in Quintlage auftretenden Accordes ver-
#  doppelt wird, sondern die Quinte. Es ist das ein bisher wenig
#  beachtetes, darum aber nicht minder wichtiges Gesetz; dessen Motivirung
#  wir nicht schuldig bleiben werden.
#  10. Der Ganztonschritt. Waren bis jetzt die Regeln
#  für den Satz sehr einfach und die Gefahren leicht zu vermeiden,
#  so fa.lt nun das Kreuz aller Harmonieschüler mit drückender
#  Last auf uns, wenn wir den Gegenquintklang direct mit dem
#  schlichten Quintklange zu verbinden suchen. Beide Klänge
#  (z. B. fr und g' in c-Dur, %h und 'a in der e-Untertonart)
#  habeni keinen Ton gemeinsam, vielmehr liegen die Töne des
#  einen von denen des andern sämmtlich eine grosse Secunde
#  nach derselben Seite entfernt:
#
#
#
#  —
#  18.
#
#  Die Stimmen in dieser Weise wirklich parallel fortschreiten
#  lassen, hiesse der Selbständigkeit der einzelnen Stimmen Hohn
#  sprechen, zumal, wenn auch noch die Bassstimme die Paral¬
#  lelbewegung mitmachte, und von Hauptton zu Hauptton resp.
#  von Mollquintton zu Mollquintton fortschritte:
#
#
#
#
#
#
#
#  19.
#
#
#
#
#
#  Regel. Ebenso wie die Octavenparallelen sind
#  auch die Quintenparallelen streng verpönt.
#  Las sehr einfache Mittel gegen Parallelen ist die der Paral¬
#  lelbewegung entgegengesetzte Gegenbewegung; diese ist
#  aber im vorliegenden Falle nur zu ermöglichen durch Absehen
#  von der streng durchgeführten Secundbewegung der drei obe¬
#  ren Stimmen:
#  II. Folgen consonanter Accorde.
#  14
#  b)
#
#  —
#
#  —
#  —
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20.
#
#
#
#
#
#
#
#  So einfach das aussieht, so bedarf es doch immerhin erst fleis¬
#  siger Übung, ehe der Harmonieschüler in der Vermeidung
#  dieser schlimmsten aller Arten von Quintenparal¬
#  lelen*) völlige Sicherheit erlangt.
#  Folgende Aufgaben mögen dazu dienen, aber womöglich
#  vermehrt werden. Sie sind auf vier Systemen auszuarbeiten
#  (Sopran und Alt mit Violinschlüssel, Tenor und Bass mit Bass-
#  schlüssel).
#  21. (Sopran.
#  a)
#
#
#
#  /
#  9
#  c 3 f 3 9
#  9
#  b)
#
#
#  3
#  e a
#  h
#  e
#  eh
#  e 3
#  e
#
#
#
#
#
#
#
#  —
#
#  —
#
#
#  0 09 04 0 à da og
#  0
#  Od da 9g 0 09 à aro
#  III
#  (Tenor.)
#  )
#  1)
#  4
#
#
#
#  +
#
#
#  1
#
#
#
#  1
#
#
#  —
#  —
#  OfO 05 0 0 0 Ob 0
#  Ocis OgisOcis cis 0. 0 cis
#  III
#  (Bass.)
#  g)
#
#
#  p
#
#
#  —
#  2
#
#
#
#
#
#  h
#  e fis
#  Nr.
#  7)
#
#
#  —
#
#  —
#
#  rs
#
#
#
#
#
#  Ogis * Ocis 9gis + 0ges * 9gis
#  *) Nämlich gerade der beim Ganztonschritt der Harmonie mögli-
#  chen. Die Gefahr verräth sich jederzeit dem ersten Blick durch die
#  Bezifferung.
#  11. Der Quintwechsel.
#  15
#  Zu bemerken ist für den Satz des Ganztonschrittes noch,
#  dass der Schritt vom Haupttone des Gegenquintklanges zur Terz
#  des schlichten Quintklanges, der Tritonus,*) (für f
#  9
#  = f — h, für % — %a = h — f) nicht leicht sanglich und
#  deshalb im Vocalsatz zu vermeiden, verrufen ist; besser ist die
#  Umkehrung des Schrittes, die verminderte Quinte h—f resp.
#  F — h.
#  II. Der Quintwechsel. Die Verbindung des Gegen-
#  quintklanges mit dem Seitenwechselklange (in c-Dur=f
#  in der e-Untertonart (a-Moll) = %— e*) ist hinsichtlich des
#  Schrittes von Hauptton zu Hauptton (f — c, h — e) ein
#  Quintschritt und zwar ein schlichter, sofern zu der dem ersten
#  Klange angehörigen Quinte fortgeschritten wird (f — c,
#  % — e); da aber bei diesem Schritte das Klanggeschlecht
#  wechselt (Dur — Moll, Moll — Dur), so wollen wir den-
#  selben »Quintwechselc nennen. Über den Satz des Schrittes
#  ist einiges zu bemerken; die Klänge haben zwei Töne gemein¬
#  sam, die dritten sind einen chromatischen Sekundschritt von
#  einander entfernt:
#
#
#
#
#
#
#  22.
#  1
#
#  Es ist aber von Wichtigkeit, dass der Übergang in den
#  chromatisch veränderten Ton in derselben Stimme
#  geschieht, oder wenigstens in derselben Octavlage von einer
#  andern Stimme gebracht wird, da sonst leicht die Harmonie-
#  folge nicht vom Ohre richtig verstanden wird und die Terz im
#  zweiten Klange als identisch mit der ersten aber verstimmt
#  erscheint; diese Ungewissheit, dieses nicht genügende Verste-
#  hen ist es, was die unangenehme Wirkung des sogenannten
#  Querstandes erklärt. Man vergleiche folgende Verbindungen:
#  (gut)
#  (schlecht)
#  22—
#  222——
#
#
#
#
#  —
#  .—
#
#
#
#
#
#  e
#  23.
#
#
#  —
#
#  —
#  —
#
#  —
#
#  —
#
#
#  *) Tritonus (griechisch) = drei Töne, denn f ist von h drei Ganztöne
#  entferrt: f — g, 9 — a, a — k.
#  16
#  II. Folgen consonanter Accorde.
#  Von einem eigentlichen Querstande kann aber auch nur beim
#  Quint wechsel die Rede sein, und folgende Verbindun¬
#  gen, welche nach der alten Lehre ebensogut querständig sein
#  müssten, wirken durchaus gut, weil über den Sinn der Har-
#  moniefolge (Terzschritt) kein Zweifel möglich ist:
#
#  —
#  %.
#  —
#
#  —
#  3
#  2
#  24.
#  8—
#
#
#  —
#
#
#  —
#  12. Der Gegenquintwechsel. Die letzte Art der mög-
#  lichen Quintschritte ist der Übergang zur Gegenquint mit
#  Wechsel des Klanggeschlechts, der » Gegenquintwechsel«
#  z. B. g* — %e oder a — et, d. h. die Verbindung des
#  Seitenwechselklanges mit dem schlichten Quint¬
#  klange. Der Satz des Schrittes läuft wie der des Ganzton-
#  schrittes Gefahr der Quintenparallelen, doch sind dieselben
#  nicht so bedenklich wie bei jenem und können geschrieben
#  werden, wenn sie durch Gegenbewegung der anderen Stimmen
#  gedeckt sind (235).
#  Ein neues Hemmniss der Stimmbewe¬
#  gung ist dagegen der übermässige Secundschritt zwi¬
#  schen den beiden Terztönen (as —
#  h. f —
#  gis); derselbe ist
#  nicht gut sanglich und muss vom Schüler gemieden werden:
#  a)
#  b)
#  besser.
#
#
#  —
#  2
#
#  —
#
#  25.
#
#
#
#
#
#  —
#
#
#
#
#
#  —
#  —
#
#
#  Die folgenden Aufgaben führen neben den früher geübten
#  Harmonieschritten auch den Quintwechsel und Gegenquint¬
#  wechsel ein. Dieselben mögen wie bisher auf vier Systemen
#  ausgesetzt werden, aber auch der Tenor im Violinschlüssel, eine
#  Octave höher geschrieben als er klingt:
#  (Sopran.)
#  a)
#
#
#  26.
#  E
#
#
#  +
#
#
#  9 6g gr o9 e g e g
#  7
#  he
#
#  "et
#  9
#  12. Der Gegenquintwechsel.
#  17
#  b)
#  .
#
#
#  —..—
#
#
#  ——
#
#  —
#
#  —
#
#
#  —.
#  1.
#  0
#  0 Ogis * Sais Ogis Odis 0 dis dis Jais gis
#  (Ait.)
#
#
#
#
#
#
#  57
#  05
#  05
#  5
#  5
#  es
#  d)
#
#
#
#
#  Ogis Ocis gis 6928 0 Ocis IIIV 0
#  Ogis
#  es
#  (Tenor.
#
#
#  —
#  —.
#  —
#
#  .
#
#
#
#
#
#  —
#  —
#  ——
#
#
#
#  —.—
#
#
#   * O esb f 0 4es f b 0h b
#
#
#
#  ———
#
#
#  .
#  —
#
#  —.—
#  Oß Oe h % 0 h Ofts %e + 0 1 + 0½
#  (Bass.) 8)
#
#
#  —
#
#
#
#
#
#
#  —
#  .—
#
#
#
#  —
#
#
#
#
#  —.—
#  09 9e | 09 %e 04 gr 09 00 | 0 * 09
#  h)
#
#  —
#  ——
#
#  .
#
#
#
#
#
#
#
#  —
#  —
#
#
#  —
#  —.—
#
#
#
#  ——
#  -
#
#  d od à a 0 0d *
#  13. Tonart. Hiermit ist der Schüler in den reinen und
#  gemischten Tongeschlechtern soweit heimisch gemacht, dass er
#  ihre Hauptaccorde zu verbinden versteht. Denn es ist das
#  Schema der reinen Durtonart:
#  Gegenquintklang — Tonika — Schlichter Quintklang
#  z. B.
#  das Schema der reinen Molltonart dagegen:
#
#  "et
#  9
#  h: d
#  fa:eeg:
#  das Schema der reinen Molltonart dagegen:
#  Schlichter Quintklang — Tonika — Gegenquintklang
#  z. B.
#  e 9
#  Schlichter Quintklang — Tonika — Gegenquintklang
#  a
#  *
#  dfac:eg:h
#  Riemann, Harmonielehre.
#  2
#  III. Die Nebenklänge der Tonart.
#  18
#  das Schema der Molldurtonart:
#  Seitenwechselklang — Tonika — Schlichter Quintklang
#  %.
#  z. B.
#
#  f: as : c:e:g: h: d
#  endlich das Schema der Durmolltonart (das gewöhnliche
#  Moll):
#  Schlichter Quintklang — Tonika — Seitenwechselklang
#  z. B.
#  da
#  e
#
#  —
#  d : f: a c: e gis: h
#  —
#  —
#  Die oben gemachte Einführung des Quintwechsels zwischen
#  Gegenquintklang und Seitenwechselklang verschmilzt Dur mit
#  Molldur und Moll mit Durmoll:
#  I. Dur:
#  Seitenwechselklang
#  — Tonika — Schlichter Quintklang
#  Gegenquintklang
#  —
#   as
#  /
#  ce:ghd
#  c
#  a
#  II. Moll:
#  Seitenwechselklang
#  Schlichter Quintklang — Tonika —
#  (Gegenquintklang
#  dfaiciequ
#  :h
#  9
#  —
#
#  Aufgabe: Aufstellung des Schema der reinen und ge¬
#  mischten Tonarten von g', d', a, et, k, fis, cis, fr b
#  es," as", des", ges", ces und 'a, °d, g, 9c, %f, %b, des, ’h,
#  Ofis, Ocis, "gis, "dis, Jais, Jeis mit Bezeichnung der Klänge als
#  Tonika, schlichter Quintklang, Gegenquintklang und Seiten¬
#  wechselklang.
#  13. Tonart. 14. Der Terzwechsel.
#  19
#  III.
#  Die Nebenklänge der Tonart.
#  %
#  14. Der Terzwechsel. Eine Betrachtung des eben ent¬
#  worfenen Schemas der reinen Tongeschlechter zeigt, dass aus
#  den Elementen zweier quintverwandten gleichartigen Klänge,
#  d. h. zweier Ober- oder Unterklänge deren einer der schlichte
#  oder Gegenquintklang des andern ist, Klänge gegentheiligen
#  Klanggeschlechts sich zusammensetzen lassen, z. B. in c-Dur:
#  0e
#  0h
#  f : a : c : e : g : h : d
#  und in der e-Untertonart:
#  und in der e-Untertonart:
#  f+
#  c+
#  d : f : a : c : e : g : h
#  Fasst man diese Gebilde, nämlich 0e0hc-Dur
#  und f+c+e-Untertonart im Sinne ihrer Zu¬
#  sammensetzung aus Elementen zweier Klänge des gegen¬
#  theiligen Klanggeschlechts auf, so müssen sie als Dissonan¬
#  zen angesehen werden. Allein diese Auffassung ist keines¬
#  wegs nöthig. Sogut neben dem Gegenquintklange der Seiten¬
#  wechselklang eingeführt werden konnte, ohne die Erwar¬
#  tung eine Modulation anzuregen, so gut oder noch besser
#  können leitereigene *) andere Klänge eingeführt werden, so¬
#  fern sie in einem verständlichen harmonischen Verwandtschafts¬
#  verhältniss zu der Tonika oder deren Quintklängen stehen. Nun
#  steht aber 0ec+
#  schrittes, oder vielmehr, da beide verschiedenen Klangge¬
#  schlechts sind, des Terzwechsels; e ist schlichte Terz von
#  c+0eTerzwechselklang von c+. Das-
#  selbe Verwandtschaftsverhältniss hat statt zwischen 0hg+
#  In der e-Untertonart ist c+0ef+
#  wechselklang von 0a
#  den Terzwechselklang des Gegenquintklanges einzuführen, d. h.
#  in c-Dur 0af+e-Unter¬
#  *) Leitereigene = aus Tönen der Tonleiter der Tonart gebildete, im
#  Gegensatze zu solchen, welche Töne enthalten, die der Tonleiter der Ton-
#  art fremd sind.
#  III. Die Nebenklänge der Tonart.
#  20
#  tonart g“ als Terzwechselklang von %h. Das geschieht denn
#  auch in der That. Die harmonische Bedeutung dieser Terz-
#  wechselklänge ergiebt sich aus ihrer Verwandtschaft, d. h. der
#  Terzwechselklang des Gegenquintklanges hat wie
#  dieser gegensätzliche Bedeutung gegen die To-
#  nika, der Terzwechselklang des schlichten Quint-
#  klanges dagegen Schlusskraft zur Tonika. Der Terz-
#  wechselklang der Tonika kann natürlich nicht die Bedeutung
#  der Tonika selbst haben, da, wenn diese auf einen andern
#  Klang übergeht, modulirt, d. h. die Tonart verlassen wird; er
#  hat deshalb nur die Bedeutung eines milden Gegensatzes.
#  Prüfen wir vorerst die Verbindung dieser Nebenklänge mit den
#  Hauptklängen, deren Terzwechselklänge sie sind, so stellt sich
#  heraus, dass der Satz des Terzwechsels überaus bequem
#  und ohne alle Gefahr ist; die Klänge haben zwei Töne ge-
#  meinsam (das grosse Terzintervall), die dritte Stimme macht
#  einen Ganztonschritt, und der Bass
#  schreitet vom Durhaupt-
#  tone zur Mollquinte fort oder umgekehrt:
#  —
#
#
#
#
#
#
#
#
#
#
#  —
#
#
#  27.
#
#
#
#
#  —
#
#
#
#
#
#
#
#
#  Eins ist jedoch über den Satz der Terzwechselklänge noch zu
#  bemerken; dieselben vertragen nämlich sehr gut die Terz-
#  verdopplung, da ihre Terzen der Hauptton und die beiden
#  Quinttöne der Tonart (Tonika, Oberquinte, Unterquinte) sind.
#  Stimmführungen, wie die folgenden sind deshalb gut zu
#  heissen :
#  *
#
#
#
#
#
#  22—
#
#
#
#
#  28.
#
#
#  —
#
#
#
#
#  —
#  —
#  —
#
#
#
#
#
#  —
#  Bei * sind überall Terzverdoppelungen.
#  Aufgabe. Zu dem am Schlusse des §. 13 entworfenen
#  Schema der Tonarten sind die Terzwechselklänge der drei Haupt-
#  15. Der Kleinterz-Wechsel.
#  21
#  accerde (Tonika, schlichter und Gegenquintklang) hinzuzu¬
#  fügen.
#  15. Der Kleinterz-Wechsel. Die Verbindung der Terz-
#  wechselklänge unter einander ergiebt keine Harmoniefolgen,
#  die wir nicht untersucht hätten, nämlich Quintschritte und den
#  Ganztonschritt (in c-Dur: %e — %a, %e — %, da — %h und um¬
#
#  gekehrt, in der e-Untertonart: c—g, c—fr. g—
#  und umgekehrt). Natürlich ist aber der Sinn der Folgen ein
#  anderer, da in c-Dur nicht % sondern 'a die Bedeutung des
#  Gegensatzes hat und in der e-Tonart nicht f sondern g'
#  Neue Harmonieschritte resultiren aber aus der Verbindung der
#  Terzwechselklänge mit den übrigen Hauptklängen. Zunächst
#  ergiebt die Verbindung der Tonika mit dem Terzwechselklange
#  des Gegenquintklanges, sowie die des schlichten Quintklan-
#  ges mit dem Terzwechselklange der Tonika einen klei-
#  nen Terzschritt mit wechselndem Klanggeschlecht, also
#  einen Kleinterz-Wechsel z. B. in c-Dur: et — % und
#  g — Ve, in der ve-Tonart: %e— g' und a—
#  c. Dieser
#  Harinonieschritt hat Gefahr der Quintenparallelen, die aber
#  durca Gegenbewegung und besonders auch durch die Terz-
#  verdoppelung im Terzwechselklange (vergl. Beisp. 28), oder
#  Quintverdoppelung im Quintklange (Hauptklange), leicht ver-
#  mieden werden; übrigens stehen dieselben in einer Kategorie
#  mit den Quintenparallelen beim Gegenquintwechsel, d. h. sie
#  sind bei weitem nicht so in's Ohr fallend und darum auch
#  weniger verwerflich als die Quintenparallelen bei Ganzton-
#  schritt:
#  b)
#  a)
#
#
#
#
#
#  m.
#
#  —m
#
#
#
#  Tun.
#
#  29.
#
#
#
#
#
#  Anm. Weder der nach unten noch der nach oben gerichtete Klein¬
#  terzwechsel kann als »schlichter« bezeichnet werden, da von den beiden
#  kleinen Terzen von e (a und es) weder die eine noch die andere dem
#  Klange c* angehört, überhaupt nicht durch Quint- und Terzschritte in der-
#  selben Richtung gefunden werden kann. Die kleine Terz ist nur mittelbar
#  mit dem Haupttone verwandt, nämlich durch Beziehung auf einen dritten
#  III. Die Nebenklänge der Tonart.
#  22
#  Ton, d. h. cf ist mit a verwandt durch f“ dem f-Klange gehört e als
#  Quint an und a als Terz, c — a ist also Übergang vom Quinttone zum Terz¬
#  tone. Wir können die Vermittelung auch in der Beziehung auf de suchen;
#  in de ist c Terzton und a Quintton; dann ist also c — a Übergang vom
#  Terztone zum Quinttone. In beiden Fällen ist der Schritt e — a ein stei¬
#  gender, wenn wir an die Obertonreihe für den Durklang und an ihre Um-
#  kehrung die Untertonreihe für den Mollklang denken:
#  Fffd.
#  * * *
#  Cede
#
#  d. h. a erscheint eigentlich als grosser Sextenschritt, in der Ober-
#  tonreihe als Übergang vom dritten Partialtone zum fünften, in der Un-
#  tertonreihe als Übergang vom fünften Partialtone zum dritten. Sehen wir
#  in dem Aufsteigen das dem Dur angemessene, in dem Herabgehen das
#  dem Moll angemessene, so dürfen wir von et aus den Schritt c —
#  a als
#  schlichten bezeichnen, c* — %a und gr— de also als schlichte Kleinterz-
#  Wechsel (oder Sextenwechsel) ansehen; entsprechend ist der Über¬
#  gang von a nach c oder von e nach g, in der Ve-Tonart als schlichter zu
#  betrachten, so dass auch hier da — er und de — als schlichte Klein¬
#  terz-Wechsel erscheinen. Für den noch unentwickelten Schüler ist es nicht
#  nöthig, dass er diese schwierigen Probleme kennt, es genügt ihm, dass
#  der Schritt e* — Oa als Übergang zum Terzwechselklange der Unterdomi¬
#  nante zu verstehen ist und als Kleinterz-Wechsel bezeichnet wird; von
#  Wichtigkeit sind für ihn nur die Gefahren seines Satzes. Ist er erst mit
#  den Terzschritten zwischen gleichartigen Klängen vertraut (cr — et,
#  0e — 9c), so wird es leicht sein, ihm begreiflich zu machen, dass der Über¬
#  gang vom schlichten Quintklange (g') zum schlichten Terzklange (et) als
#  schlichter Kleinterz-Schritt bezeichnet werden muss (g— e*) und dass,
#  wenn bei diesem Schritte das Klanggeschlecht wechselt, (g* — Oe) der
#  Schritt zum schlichten Kleinterz-Wechsel wird. Man verschiebe also die
#  Aufklärung bis dahin.
#  16. Der Leittonwechsel. Die Verbindung der Tonika
#  mit dem Terzwechselklange des schlichten Quintklanges (ct—
#  0h; %e — f'), sowie die des Gegenquintklanges mit dem
#  Terzwechselklange der Tonika (/ — %e; % — c*) ergiebt
#  eine neue Harmoniefolge. Der Schritt von Hauptton zu
#  Hauptton ist, in nächste Nähe gerückt, ein Leittonschritt:
#  c — h, e —J; f—e; h—c; da h Terz der Quint von
#  c, resp. f Unterterz der Unterquint von e ist, so sind sämtli¬
#  che Schritte schlichte (h ist 15. Oberton von e“, f 15. Unter¬
#  ton von %e); da das Klanggeschlecht bei denselben wech-
#  selt, nennen wir sie »Leittonwechsel«. Der Satz des Schrittes
#  16. Der Leittonwechsel. 17. Der Ganztonwechsel.
#  23
#  wetteifert mit dem Terzwechsel an Leichtigkeit und an Un-
#  möglichkeit, Fehler zu machen, da die Klänge zwei gemein¬
#  same (liegenbleibende) Töne haben, die dritte Stimme einen
#  Leittonschritt macht und der Bass unbehindert vom Durhaupt-
#  ton zur Mollquinte und umgekehrt fortschreiten kann:
#
#
#
#
#
#
#
#
#
#
#
#  .
#
#  30.
#
#
#  —
#
#
#
#  S
#
#  —
#
#  —.—
#
#  —
#  17. Der Ganztonwechsel. Der Terzwechselklang des
#  Gegenquintklanges steht zum schlichten Quintklange im Ver-
#  hältniss des »Ganztonwechsels«, d. h. die Entfernung der
#  Haupttöne beträgt einen Ganzton und das Klanggeschlecht
#  wechselt (in c-Dur = Ja — g“; in der e-Tonart = g'— a);
#  die Bedeutung des Schrittes ist, da der Terzwechselklang des
#  Gegenquintklanges an dessen gegensätzlicher Bedeutung parti¬
#  cipirt, ganz und gar die des Ganztonschrittes (§ 10), d. h. des
#  Überganges vom Gegenquintklange zum schlichten Quintklan¬
#  ge, er macht wie dieser einen vortrefflichen Schluss zur Tonika.
#  Sein Satz ist leicht und gefahrlos; es ist ein gemeinsamer Ton
#  da, zwei Stimmen machen Ganztonschritte und der Bass schrei¬
#  tet vom Mollquint- zum Durhaupttone fort oder umgekehrt—
#  kein Wunder, dass er oft genug statt des quintengefährlichen
#  Ganztonschrittes zur Anwendung kommt:
#  b)
#  a)
#  0——
#
#
#
#  —6—
#  m
#
#
#
#
#
#
#  31
#
#  2—
#
#
#
#
#
#
#  E
#
#  Anm. Eine besondere Wichtigkeit gewinnt der Ganztonwechsel für
#  die Modulation. Da nämlich der Ganztonschritt eine Schlusskraft
#  zu dem übersprungenen gleichartigen Klange hat, z. B. c
#
#  dr zu gr (c— 9 — d), so wird er sehr häufig zu einer vorwärts schrei¬
#  tenden Modulation (für Dur zu einer steigenden, für Moll zu einer fallen-
#  den) benutzt; der Ganztonwechsel dagegen wird vorzugsweise benutzt zu
#  rückwärts gewandter Modulation, da das Verhältniss der Haupttöne des-
#  III. Die Nebenklänge der Tonart.
#  24
#  selben niemals als das der doppelten Quint verstanden wird, was beim
#  Ganztonschritt gewöhnlich geschieht, also bei % — g* das a nicht als
#  zweite Quint von g (9 — d— a) verstanden, sondern immer in dem Sinne,
#  dass a Terz der zweiten Unterquint von g ist. g—
#  Oa führt gaher nicht.
#  nach g-Dur, sondern zurück nach c-Dur.
#  18. Der Tritonuswechsel. Die letzte mögliche Combi-
#  nation der Terzwechselklänge mit den Hauptklängen ist die
#  Verbindung des Gegenquintklanges mit dem Terzwechselklange
#  des schlichten Quintklanges. Das Verhältniss der Haupttöne
#  ist das des Tritonus; da das Klanggeschlecht wechselt, nen-
#  nen wir den Schritt »Tritonuswechsel. Seine Bedeutung ist
#  die des Ganztonschrittes und Ganztonwechsels, er schliesst zur
#  Tonika. Die Gefahr der Quintenparallelen, deren Qualität
#  dieselbe ist wie die des Gegenquintwechsels und Kleinterz-
#  wechsels, wird vermieden durch Gegenbewegung und Terzver-
#  doppelung (s. Beispiel 28); auch können die Parallelen zwi-
#  schen einer Aussenstimme und einer Mittelstimme geschrieben
#  werden, müssen aber durch Gegenbewegung einer andern Stim¬
#  me verdeckt werden. Schreibt der Schüler solche Parallelen,
#  so muss er durch Parallelstriche anzeigen, dass er sie gesehen
#  hat, womöglich auch andeuten, wie sie hätten vermieden
#  werden können. Es giebt viele Fälle, wo der Satz
#  mit Quintenparallelen wohlklingender ist, als ohne
#  dieselben; in solchen Fällen darf der Schüler die Paralle-
#  len schreiben, aber er muss wissen, warum er es gethan :
#  b)
#  a)
#
#
#
#
#
#  T.
#
#
#
#
#
#
#
#
#
#
#  32.
#
#
#
#
#
#
#
#
#  —
#
#
#
#  Die nun folgenden Beispiele führen die Terzwechselklänge
#  in allen ihren verschiedenen möglichen Verbindungen mit den
#  Hauptklängen ein. Ihre Zahl ist mit Rücksicht auf den Um-
#  fang dieses Schriftchens klein bemessen und muss vom Lehrer
#  erheblich vermehrt werden, wenn ein Schüler hiernach unter-
#  richtet werden soll. Überhaupt muss ich immer wieder beto-
#  nen, dass es sich für mich mit dem gegenwärtigen Schrift-
#  chen nicht um eine ausgeführte Harmonielehre, sondern nur
#  L.
#  18. Der Tritonuswechsel.
#  25
#  um die Skizze einer solchen handelt. Vor allem soll die von
#  mir vorgeschlagene neue Bezifferung (der Klangschlüssel) prak-
#  tisch vorgeführt werden.
#  Die Aufgaben sollen von jetzt ab auf vier Sy-
#  stemen mit den vier für die Aufgabe gebrauchten
#  Schlüsseln: (Discant-, Alt-, Tenor- und Bass-
#  schlüssel) ausgesetzt werden.
#  a)
#
#  33.
#  +
#  —
#  E
#
#  3
#  0 9 0 e a 5 g
#  0a
#  III
#  b)
#  —
#
#  —
#
#
#
#  —
#  —
#
#
#
#
#  c
#  a e Oeis Ofis 0 cist Oets
#  Ocis Ofts e Ogis 0
#  5
#
#
#  —
#  Eer
#
#
#
#
#  —
#  —
#
#
#  —
#  bo4 09 da es 5 f * 0 09f b
#  —
#
#
#
#
#
#
#
#  +
#
#
#  —
#  Ofts % ar d 0 0fts + 0 % * 1 * 0
#  e)
#  —
#  1.5
#
#
#  +
#
#  —
#
#  —
#  —
#  —
#
#
#
#  1
#  t—
#  F Od
#  f de d da de Sde)
#  f)
#  —
#
#  2
#
#
#  —
#
#
#  —
#  —
#
#  —
#
#  0½ hr 05 9 0e 9 0 0e 0 + 0½
#  g) Vgl. Richter 70. 4.
#  —
#  A
#
#
#  2—
#  —
#  —
#
#
#
#  —
#  —.
#
#
#  9a
#
#  3 d
#  e gdohe 9 de d
#  h) Richter 70. 7.
#  —
#
#
#
#
#  T
#
#
#
#  —
#  —
#  —
#  3 5
#  da 0d f 0d fe
#  III. Die Nebenklänge der Tonart.
#  26
#  1)
#
#
#  Oe
#  Da 0
#  Oe
#
#  e
#  e 02
#  h
#  k)
#  521.
#
#  —
#
#
#
#
#
#  —
#
#  —
#
#
#
#  à Oh
#  Ofts % 0e
#  Oe Ofts
#  19. Der Terzschritt. Einige neue Harmonieschritte er¬
#  geben sich noch aus der Verbindung des Seitenwechselklanges
#  der Tonika mit den Terzwechselklängen, nämlich zunächst
#  zwischen dem Terzwechselklange der Tonika und ihrem Seiten-
#  wechselklange ein Terzschritt, in c-Dur: %e — %c, in der e-Un-
#  tertonart: c“— ef. Der Schritt ist, in dieser Richtung (zu
#  dem Klange der dem ersten Klange angehörenden Terz), ein
#  schlichter, seine Bedeutung ist aber darum, weil der erste
#  Klang nicht die Tonika selbst ist, nicht ganz die sonst schlich-
#  tem Schritte eigene. Erst später, wenn wir von der Tonika
#  selbst aus schlichte und Gegenterzschritte ausführen, werden wir
#  deren Bedeutung als völlig der der schlichten- und Gegen-
#  quintschritte entsprechend kennen lernen. Der Satz der Terz¬
#  schritte macht keine Schwierigkeiten, hat aber eine Eigen-
#  thümlichkeit, nämlich einen chromatischen Secundschritt
#  a — as, resp. 9 — gis) ; schon oben (§. 11) ist darauf hinge¬
#  wiesen worden, dass eine querständige Wirkung beim Terz-
#  schritt nicht in gleichem Masse zu befürchten ist, wenn der
#  chromatisch veränderte Ton von einer anderen Stimme, in an¬
#  derer Octavlage gebracht wird; doch wird diejenige Stimme,
#  welche eben a gesungen hat, das as leichter treffen als eine
#  andere, welcher das a als von jener gesungen im Ohre liegt
#  und daher leicht statt des as von ihr gebracht werden wird:
#  NB.
#  NB.
#
#
#
#  E
#  34.
#
#
#  2——
#
#
#
#  —t
#
#  ——
#
#  2
#
#  Eine Stimmführung wie bei NB. wird darum nur sehr aus-
#  nahmsweise gewählt werden, weil sie keines der natürlichen
#  Bindemittel (liegenbleibender Ton, Leittonschritt, chromatische
#  Fortschreitung) benutzt, sondern in allen Stimmen springt.
#  20. Der Kleinterzschritt. 21. Der Leittonschritt.
#  27
#  20. Der Kleinterzschritt. Der Terzwechselklang des
#  Gegenquintklanges steht zum Seitenwechselklange im Verhältniss
#  des Kleinterzschritts, in c-Dur: °a — %c, in der e-Untertonart
#  9— e. Der Schritt ist wie aus dem §. 15. Anm. gesagten
#  hervorgeht, ein schlichter, wenn er in dieser Richtung ge-
#  schieht. Auch der Kleinterzschritt weist eine chromatische
#  Fortschreitung auf (as — a, e —
#  gis), ist übrigens für den Satz
#  ohne Gefahren und Schwierigkeiten:
#
#
#
#
#
#  —
#  35.
#
#
#
#
#
#  21. Der Leittonschritt. Der Terzwechselklang des
#  schlichten Quintklanges endlich steht zum Seitenwechselklange
#  —
#  im Verhältniss des (schlichten) Leittonschrittes, in c-Dur
#  % — %, in %e =/ — e Sämtliche Stimmschritte sind bei
#  der einfachen Nebeneinanderstellung der Klänge Leitton¬
#  schritte; die für den vierstimmigen Satz resultirende Gefahr
#  der Cluinten-- und Octavenparallelen (36 a.) ist nicht leicht zu
#  vermeiden, weil der Gegenbewegung sich der übermässige Se-
#  kundschritt (36 b.) hindernd in den Weg stellt. Der beste
#  Ausweg ist Verdoppelung der Terz im Terzwechselklange (c):
#  a)
#  c)
#
#
#
#
#
#
#
#  —
#
#
#
#  —
#
#
#  36.—
#  —
#  —.—
#  —
#  —
#  .
#  S. au. S.
#
#  Zur Übung im Satze des schlichten Terzschrittes, Klein¬
# ...
#  Willen, oder aber dass der Autor die bequemere enharmonisch¬
#  identische Schreibweise vorgezogen hat, z. B. wird sich häufig
#  as— e finden statt asfes ein Doppelterzschritt statt des
#  einfachen, der aber doch nur ein einfacher ist; das gleiche gilt
#  von as— h' statt as
#  ces“ u. 8. w.
#  Die enharmonische Verwechslung hat aber eine zwiefache
#  Bedeutung für unsere Musik. Soweit sie nur in der angedeu¬
#  teten Weise die Denkarbeit des Notenlesens erleichtert, berührt
#  sie nur die Oberfläche der Musik; sofern sie aber vom Com-
#  ponisten benutzt wird, ohne dass er ihrer innerlichen anderen
#  Bedeutung Rechnung trägt, greift sie tief in das Wesen der
#  Harmonik ein. So schreibt z. B. Beethoven im Trauermarsch
#  der Sonate Op. 26 statt ces -Moll der Erleichterung wegen
#  h-Moll und modulirt dann über d-Dur. b-Dur, es-Dur zurück
#  nach as-Moll; dieses nunmehr erreichte as-Moll würde aber
#  ohne die enharmonische Verwechselung des ces-Moll in h-Moll
#  bbbh-Moll*) sein; d. h. die Modulation kehrt nicht wieder zur
#  Ausgangstonart zurück, sondern erreicht eine enharmonisch mit
#  ihr identische (wenigstens im System der gleichschwebenden
#  Temperatur). Derartige Beispiele sind sehr häufig. Wieder
#  anders wirkt die Enharmonik, wenn sie nur einem einzigen
#  Accorde angehört z. B.
#  be¬
#  0—
#  2—
#
#
#
#
#
#  107.
#
#  89 89 03
#  Oe
#  Der Übergang von de nach %5 ist hier durch Gleichsetzung (en-
#  harmonische Identification) von 2" und &° (vgl. § 27) der un¬
#  gezwungenste von der Welt geworden, doch nur auf dem
#  Papiere; denn in demselben Augenblick wo wir den Accord
#  im letzteren Sinne fassen, ist seine erste Bedeutung spurlos
#  verschwunden und das &2 steht nachträglich unvermittelt neben
#  *) Soviel mir bekannt, existiren die Tripelbeen und Tripelkreuze nur
#  in dem Lehrbuch der Harmonik von Oskar Paul (1880) S. 28 ff., welcher
#  deren für die von ihm erfundene verminderte Secunde und Sexte, sowie
#  die vor ihm gleichfalls noch nicht bekannte übermässige Septime bedarf,
#  während ihm die verminderte Octave ein unbekanntes Ding ist.
#  39. Enharmonische Verwechselung.
#  83
#  de als Tritonuswechsel. Diese Art von Enharmonik ist trüge¬
#  risch und sollte weit vorsichtiger benutzt werden als sie that-
#  sächlich wird.
#  40. Direct verständliche Harmonieschritte. Wie aus
#  der obigen Zusammenstellung der Harmonieschritte zu ersehen,
#  können eine sehr grosse Anzahl leiterfremde Accorde einge¬
#  führt werden, ohne dass die Tonart verlassen wird. Die wei-
#  ter ausgreifenden werden der Tonika diesen oder jenen schlich-
#  ten oder gegensätzlichen Seitenklang mit Nachdruck gegen-
#  überstellen, zu welchem sie als das Verständniss vermitteln-
#  dem hinführen; die direct gegen die Tonika verständlichen aber,
#  deren auch nicht wenige leiterfremd sind, werden nicht ein¬
#  mal das thun, sondern einfach als bezogene Klänge der To-
#  nika gegenüberstehen ohne jede Gefährdung der Tonalität.
#  Die zu directer Gegenüberstellung geeigneten Klänge, welche
#  zur Tonika zurück leitend eine mehr oder minder intensive
#  Schlusskraft haben, mögen hier in übersichtlicher Zusammen¬
#  stellung Platz finden:
#  108.
#  3.
#  2.
#  4.
#
#
#
#
#
#
#  —
#
#
#
#
#
#  —
#  a)
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2
#
#
#
#  f—
#
#
#  —
#
#  He
#  b)
#
#
#  6
#
#
#
#
#
#
#
#
#
#
#
#  6
#  8.
#  9.
#  7.
#  —
#  —
#  —
#
#
#
#
#
#
#
#  2)
#
#
#
#
#
#
#  5.
#
#
#  C
#
#
#  be
#
#
#  —
#
#  —
#
#  b)
#
#  -
#
#
#  6*
#  a)
#  b)
#  VIII. Tonalität.
#  84
#  10.
#  11.
#  12.
#
#
#  +
#
#  —
#
#
#
#
#  a)
#
#  4
#
#  —
#
#
#
#
#  .
#
#
#  b)
#
#
#
#
#
#
#
#
#
#
#
#  13.
#  19.
#  18.
#
#
#
#
#
#
#
#
#
#  —,
#
#  4
#
#
#
#
#
#  A Va.
#
#
#
#
#
#
#  Ble-
#  (.
#
#
#
#
#
#  H—
#
#
#
#  2
#  21.
#  20.
#  a)
#
#  E
#
#  2
#  2
#
#  b)
#
#
#  —
#
#
#
#
#  (Die Nummern und Buchstaben beziehen sich auf die Aufstellung im
#  vorigen Kapitel.)
#  Viele dieser Sätzchen sind für den Vokalsatz kaum brauch-
#  bar, weil der Sänger zu sehr von seinem an dieselben nicht
#  gewöhnten Ohre abhängig ist, vor allem der ungeschultere
#  Chorsänger. Dagegen wüsste ich keinen Grund, trotz aller
#  chromatischen Fortschreitungen und enharmonischen Halte¬
#  töne, für den Instrumentalsatz, Dinge wie 9, 13, 21 zu verbie-
#  ten; es wird nur darauf ankommen, sie am rechten Platze zu
#  verwerthen. So hat z. B. Max Bruch mit grossem Glück die
#  Terzschritte zwischen Mollaccorden (6b und 7b) für den schwer-
#  müthig-ernsten Ton der Glocke in seinem »Liede von der
#
#  a)
#  40. Direct verständliche Harmonieschritte.
#  85
#  Glocke« verwerthet. Viele Harmonieschritte werden wesent-
#  lich leichter verständlich oder für die Stimmführung beque-
#  mer, wenn Dissonanzen hinzutreten, besonders gilt das für
#  die Einführung der Mollseptime. Folgende Beispiele mögen
#  davon einen Begriff geben:
#  VII
#  VII
#  VII
#  4.
#  5.
#  1.
#  109.
#
#
#
#
#  e—
#
#
#  a)
#  —
#
#  M
#
#  .
#  —
#
#
#
#
#  —
#
#  b)
#
#  —
#
#  —
#
#
#
#
#
#
#
#
#
#  VII
#  VII
#  VII
#  VII
#  VII
#  10
#  8.
#  7.
#  6.
#
#  —
#
#
#  sth
#
#  a)
#
#  —
#
#
#  ..
#
#
#
#  ..
#  —.
#  —
#
#
#
#
#
#
#
#
#
#  —
#
#
#
#
#
#  VII
#  VII 7
#  VII
#  VII
#  7
#
#  6 7.
#  VII
#  VII
#  15.
#  13.
#  14.
#  12.
#  11.
#
#  bha
#
#
#
#
#
#
#
#
#  S
#
#
#
#
#
#
#
#
#
#
#  t
#
#
#
#
#  7 VI VII VII VII
#  VII VII
#  86
#  a)
#  b)
#  a)
#  b)
#  VIII. Tonalität.
#  7
#  7 VII
#  VII
#  VII
#  7
#  16.
#  18.
#  17.
#  19.
#  21.
#
#  —
#
#
#
#
#
#  —
#
#
#
#
#
#  —
#
#  I
#
#  2
#
#
#
#
#
#
#  —
#  —
#  L
#  3
#
#  —
#
#  1
#
#
#  —
#  —
#  —
#
#
#
#
#
#
#  VII 7. VII 7
#  VII
#  7 VII
#  VII VI
#  7
#  7
#  22.
#  23.
#
#
#
#
#
#
#
#
#  ft—
#
#
#  .
#  —
#  n¬
#  6
#
#  —
#
#
#
#  —.
#
#
#
#
#  b¬
#  VII
#  VII
#  41. Modulation. Der Umfang dieses Schriftchens würde
#  ein viel zu grosser werden, wollte ich methodisch die Lehre
#  von der Modulation abhandeln und successiv den Harmonie¬
#  schüler an die Übergänge in immer entferntere Tonarten ge-
#  wöhnen. Der Zweck dieser »Skizzec, für eine neue Methode,
#  sei es die hier skizzirte selbst oder eine andere gleicher Ten¬
#  denz, in weiteren Kreisen Meinung zu machen, würde schon
#  halb verfehlt sein, wenn der Kaufpreis derselben ein zu hoher
#  würde. Aus diesem Grunde muss ich mich auf wenige ab¬
#  schliessende Bemerkungen beschränken.
#  Klänge, die nicht leitereigen und darum für unser an die
#  leitereigene Harmonik gewöhntes Ohr auffallend sind, werden
#  am besten auf einem gut betonten Takttheile auftreten; es ist
#  eine bekannte Thatsache des musikalischen Auffassens, dass
#  wir den accentuirt auftretenden Harmonien eine grössere Auf¬
#  merksamkeit schenken als den accentlosen. Tritt daher ein
#  Klang, der eine Modulation einleiten oder doch wenigstens bei
#  bleibender Tonalität zu einem fern stehenden Klange führen
#  soll; accentlos auf, so passirt es leicht, dass er nicht genu¬
#  gend aufgefasst und die ganze Wendung daher nicht begriffen
#  41. Modulation.
#  87
#  wird. Die dadurch entstehende unangenehme Wirkung ist
#  ganz dieselbe wie beim Querstand (§. 11). Ähnliches gilt von
#  den Dissonanzen, auch den der Tonika näher stehenden, be¬
#  sonders aber den Vorhaltsdissonanzen; die Regel ist, dass der
#  Vorhalt accentuirt und seine Auflösung accentlos auftritt,
#  wenigstens schwächer accentuirt (wenn nicht die Auflösung
#  vermieden und in eine neue Dissonanz übergegangen wird,
#  die dann allerdings auch wieder accentuirt auftreten wird).
#  Durchgehende Dissonanzen, d. h. solche, welche durch stufen¬
#  weise Fortschreitung mit oder ohne liegenbleibende Töne ent¬
#  stehen:
#  können dagegen jederzeit accentlos auftreten. Ein ausserge¬
#  wöhnlicher ihnen in solchem Falle gegen das Metrum verlie¬
#  henen Accent bereitet auf eine Modulation vor; denn er
#  aversirt uns, dass der Accord mehr als eine Durchgangsbedeu¬
#  tung haben soll.
#  Modulation ist Wechsel der Tonalität, d. h.
#  Übergang der Tonikabedeutung auf einen anderen
#  Klang. Da erste Bedingung und Cardinaleigenschaft jedes
#  wahren Kunstwerkes Einheit ist, welche im musikalischen
#  Kunstwerke zuerst und zuoberst als Einheit der Tonart er¬
#  scheinen muss, so wird ein guter Meister in der Art, wie er
#  modulirt, seine Künstlerschaft recht zeigen können. Nicht
#  dass er es vermeiden sollte, die Haupttonart zu verlassen —
#  im Gegentheil! nicht Einförmigkeit und Einerleiheit, sondern
#  Einheit soll dem Kunstwerke eignen, Einheit in der Vielge-
#  staltigkeit. Die Kunst ist, eine reiche Harmonik bei bleiben¬
#  der Tonalität zu entfalten und wo Modulationen geschehen, diese
#  so zu ordnen, dass das Bewusstsein der Haupttonart nicht
#  verloren geht. Die an Stelle der verlassenen gesetzte Tonart
#  soll nicht als etwas ganz anderes, fremdes erscheinen, sondern
#  als eine Nebentonart, als ein dem verlassenen angrenzendes
#  Gebiet. Mit andern Worten: der Übergang in eine andere
#  VIII. Tonalität.
#  88
#  *
#  Tonart ist ewas ganz Ähnliches wie der Übergang von einem
#  Klange zu einem anderen; dem Unterschiede der Tonika und
#  der bezogenen Klänge entspricht der Unterschied der Haupt¬
#  tonart und ihrer Nebentonarten. Die Modulation steht
#  also im Bann einer Tonalität höherer Ordnung.
#  42. Tonartenverwandtschaft. Die Verwandtschaft der
#  Tonarten ist nach der Verwandtschaft der Toniken zu beurthei¬
#  len. Nächstverwandte Tonarten sind daher diejenigen, deren
#  Toniken gegen die Haupttonika direct verständlich sind, also in
#  erster Linie :
#  I.
#  Die Seitenwechseltonart (Toniken: c' — %c;
#  9 —
#  et).
#  II. Quinttonarten:
#  a) (Schlichte) Quinttonart (Toniken: e' — g';
#  e —
#  a).
#  b) Gegenquinttonart (Toniken: c'—f; e—h°).
#  c) Quintwechseltonart (Toniken: — 69;
#  e —
#  at).
#  III. Terztonarten:
#  a) (Schlichte) Terztonart (Toniken: c'— et; e—%).
#  b) Gegenterztonart (Toniken: e“ — as“; de —°gis).
#  c) Terzwechseltonart (Toniken: c—%e; e— c*).
#  IV.
#  Kleinterztonarten:
#  a) (Schlichte) Kleinterztonart (Toniken: c — a;
#  8e —
#  0g).
#  b)
#  Gegenkleinterztonart (Toniken: e“ — est;
#  — Ocis).
#  V. Leittonwechseltonart (Toniken: — %;
#
#  0—
#  Die ältere Lehre von der Tonartverwandtschaft nahm einzig
#  die Gemeinsamkeit der harmonischen Mittel als Maassstab für
#  den Grad der Verwandtschaft und kam dabei zu dem der
#  Praxis der Componisten und dem Gefühle des Musikers wider¬
#  sprechenden Resultate, dass z. B. die Tonarten der zweiten
#  Quinten (Ganzton-Tonarten) nähere Verwandte sein sollten als
#  die gleichartigen Tonarten der Terzen; es war das die noth-
#  wendige Folge der Ableitung des Tonartbegriffes von der Ton¬
#  leiter. Heute ist diese irrige Anschauung definitiv überwun¬
#  42. Tonartenverwandtschaft
#  89
#  Die Tonarten der zweiten Classe werden für Durchführungs-
#  den, seit unsere Componisten, der nachhinkenden Theorie zum
#  Trotz, die Terztonarten der Haupttonart wiederholt direct ge¬
#  genübergestellt haben.
#  Verwandte zweiter Ordnung sind:
#  VI. Die Tonarten der zweiten Quinten:
#  a) Tonart des (schlichten) Ganztonschrittes
#  (Toniken: e — dr; de — 0d).
#  b) Tonart des Gegenganztonschrittes (Toni¬
#  ken: e— br %e — Ofis).
#  c) Tonart des Ganztonwechsels (Toniken: c“—
#  od; %e — d*)
#  d) Tonart des Gegenganztonwechsels (Toni-
#  ken: c— %; %e — fis“)
#  VII. a)
#  Die Tonart des Kleinterzwechsels (Toni¬
#  ken: e — °a; %e — g*).
#  b)
#  Die Tonart des Gegenkleinterzwechsels
#  (Toniken: c— es; e— cis*)
#  VIII. Die Tonart des Gegenquintwechsels (Toni¬
#  ken: e— %; %e — h*).
#  IX. Die Leittontonarten:
#  a) Tonart des steigenden Leittonschrittes
#  (Toniken: c“ — des ; °e — %f).
#  b) Tonart des fallenden Leittonschrittes (To¬
#  k; e — dis).
#  niken: c
#  X. Die Tonart des Gegenterzwechsels (Toniken:
#
#  das; e — gis
#  XI. Die Tonart des Tritonuswechsels (Toniken:
#  5*
#
#  Ofts; de —
#  XII. Die Tonart des Doppelterzwechsels (Toni-
#  ken: c"—
#  Ogis; 'e — as
#  Die Tonarten der zweiten Classe werden für Durchführungs¬
#  theile, die der ersten für die Gegenüberstellung der Neben¬
#  themen geeignet sein. Eine ausführlicher angelegte Methode
#  der Harmonielehre wird die Modulation nach den verschiede¬
#  nen Tonarten einzeln in zahlreichen Beispielen üben müssen,
#  damit dem Schüler die verschiedenen möglichen Wege geläufig
#  werden (vergl. meine leider in der früher von mir gebrauchten
#  unpraktischen griechischen Terminologie abgefasste Brochüre
#  »Die Hülfsmittel der Modulation«, Cassel, 1875).
#  VIII. Tonalität.
#  90
#  43. Freie Übungen. Nebenhergehend neben den Aus-
#  arbeitungen der Aufgaben mit Bezifferung, muss früh der Schü¬
#  ler anfangen, gegebene Melodien (Choralmelodien, Volkslieder
#  etc.) selbst zu beziffern und dann auszusetzen; diese Übungen
#  können zugleich Vorübungen für den Orchestersatz sein, wenn
#  der vierstimmige Satz in verschiedenartiger Weise speziell für
#  Instrumente bestimmt wird, z. B.
#  a) für Streichquartett (wobei auf die Grenze der
#  Violinen und Bratsche nach der Tiefe (9 resp. c) aufmerksam
#  oder:
#
#
#  zu machen ist). Schlüssel:
#
#
#  b) für vier Hörner (Ventilhörner in F, die eine Quinte
#  höher geschrieben werden als sie klingen, und ohne Vorzei-
#  chen; Grenze nach der Höhe c“, nach der Tiefe c). Schlüs-
#  sel: 4
#  Violinschlüssel.
#  für 2 Ventilhörner in F und 2 Fagotten, das zweite
#  c)
#  Fagott im Bassschlüssel, das erste im Tenorschlüssel.
#  d) für Oboe, B-Clarinette, Ventilhorn in F und Fagott;
#  Ton tiefer als sie geschrieben
#  die B-Clarinette klingt einen
#  wird. Grenze der Oboe nach der Tiefe h; für die Clarinette
#  d, u. s. f.
#  Von äusserst erziehlicher Bedeutung sind Analysen klassi-
#  scher Compositionen, die sich zunächst nur auf die harmonische
#  Struktur beziehen müssen; der Schüler beziffre zunächst Ada¬
#  gio-Sätze Beethovenscher Sonaten, Streichquartette, Trios etc.,
#  der vorgerücktere chiffrire auch die Partituren der Sympho-
#  nien. Zuletzt werde auch die Bezifferung Bachscher Fugen
#  versucht, die sich wegen der durch alle Stimmen fortgesetzten
#  melodischen Umrankung der Harmonien (durchVorhalte,
#  Wechsel- und Durchgangstöne) als sehr schwierig herausstellt.
#  Sodann erfinde der Schüler frei kleine Sätzchen, zunächst
#  achttaktige ohne Modulation, später zweitheilige (16-taktige),
#  die im ersten Theile nach einer nahverwandten Tonart moduli¬
#  ren und im zweiten sich zur alten Tonart zurück wenden.
#  Schon früh muss endlich die Belebung des vierstimmigen
#  Satzes durch Einführung von Noten doppelter Geschwindig-
#  keit geübt werden; diese Übungen können etwa ihren Anfang
#  nehmen nach Kenntniss sämmtlicher Harmonieschritte der Ton¬
#  43. Freie Übungen.
#  91
#  art im alten Sinne (leitereigen). Sie sind in der Weise ein¬
#  zuleiten, dass in zuerst Note gegen Note ausgesetzten Beispie¬
#  len der Versuch gemacht wird, die Bassstimme in doppelte
#  Bewegung zu bringen, wobei sich die Gefahren der Octaven-
#  und Quintenparallelen als erheblich vermehrt herausstellen
#  werden; die Mittel der doppelten Bewegung sind:
#  a) nachschlagende Accordtöne,
#  b) Durchgangstöne und Wechseltöne,
#  c) vorbereitete Vorhalte,
#  d) frei auftretende Vorhalte,
#  e) Anticipationen.
#  Ist der Versuch mit der Bassstimme geglückt, so werde das-
#  selbe mit einer andern Stimme versucht (an anderen Beispie¬
#  len, oder aber an denselben Beispielen ohne figurirte Bass¬
#  stimme). Sodann werde die Durchführung der doppelten Be-
#  wegung in der Weise versucht, das bald in dieser, bald in je-
#  ner Stimme die nachschlagenden Töne auftreten. Endlich
#  schreite man zur verdreifachten und vervierfachten Bewegung
#  und zuletzt zur Durchführung eines oder mehrerer Motive in
#  der Figuration. Der Gewinn von diesen Übungen wird ein
#  grosser sein, in doppelter Beziehung: erstens entwickeln sie die
#  Gewandtheit im Contrapunktiren ausserordentlich, und zwei¬
#  tens wird dem Schüler das Stimmgewebe polyphoner Compo¬
#  sitionen durchsichtig, so dass er überall deutlich den harmo-
#  nischen Kern hindurch sieht.
#  Ein Beispiel mag ohngefähr andeuten, in welcher Weise
#  diese Übungen zu machen wären (Sopran gegeben):
#  a) Note gegen Note.
#  (Vom Schüler sind die Beispiele in vier Schlüsseln zu setzen.)
#  * 5 b. f7 b f „ b es J *
#  111.
#
#  —
#  —
#
#
#
#  1—
#
#  I—
#
#
#
#
#
#
#
#  2
#
#
#
#
#  4—
#
#
#
#
#
#
#  2
#  2
#  2
#  2
#  —
#
#
#  4
#
#
#
#
#
#
#
#  —6—
#
#
#  —
#
#
#  —
#  VIII. Tonalität.
#  92
#  b) Bass in Vierteln.
#
#
#
#  —
#
#
#
#
#
#
#
#
#  2
#  —
#
#
#
#
#
#
#
#
#  .
#
#  2
#  —
#
#  ——
#
#
#
#
#
#
#
#
#
#
#  c) Alt in Vierteln.
#
#
#
#
#
#
#
#  —
#
#  ——
#
#
#
#
#
#  —
#
#
#  9
#
#
#
#
#
#
#
#
#
#
#
#
#  d) Hertheilte Bewegung
#  —
#
#
#  —
#
#
#
#  .
#  2
#
#
#
#
#  EL
#
#  —
#
#
#
#  e) Achtel und Viertel gemischt.
#
#  —
#
#  h
#  ——
#
#  3—
#  ——
#
#
#
#  —
#  SK.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  6
#  .
#
#
#
#  6
#
#
#
#  9
#
#
#
#
#  —.—
#  2
#
#  —6—.
#  —
#  —

# %% [markdown]
# ## Export named entities

# %%
def export_named_entities(path):
    
    tree = etree.parse("Riemann1880.xml")
    nsmap = {
        None: "http://www.tei-c.org/ns/1.0",
    }
    
    body = tree.find("//body", namespaces=nsmap)
    assert body is not None
    
    #useful vs "useless" nodes
    structure = {'lb', 'hi', 'ab', 'pb', 'p', 'div', 'head'}
    useful = {'musical_concept', 'unclear', 'rs', 'work', 'date', 'complex_expression'}
    
    counter = Counter()
    
    page = 0
    named_entities = dict()
    i = 0
    
    for element in body.iterdescendants():
        
        tag = element.tag
        
        #remove nsmap
        if "}" in tag:
            tag = tag[tag.index("}")+1:]
            
        #page break
        if tag == "pb":
            page += 1
            
        #entities: either "rs" with an attribute (when default tags), or custom tag
        if tag in useful:
            named_entities[str(i)] = {}
            
            if tag == "rs":
                named_entities[str(i)]['tag'] = element.attrib.get("type")            
            else:
                named_entities[str(i)]['tag'] = tag

            named_entities[str(i)]['text'] = element.text
            named_entities[str(i)]['page'] = page
        
        counter[tag] +=1
        i += 1
    
    name = path.split('.')[0]
    
    #save in json file
    with open(f'{name}_ner_tags.json', 'w', encoding='utf-8') as file:
        json.dump(named_entities, file)
    return named_entities

# %%
export_named_entities(path)
# Out:
# {'8': {'tag': 'person', 'text': 'DR. HUGO RIEMANN', 'page': 1},
#  '10': {'tag': 'place', 'text': 'LEIPZIG', 'page': 1},
#  '12': {'tag': 'org', 'text': 'BREITKOPF UND HÄRTEL', 'page': 1},
#  '14': {'tag': 'date', 'text': '1880', 'page': 1},
#  '18': {'tag': 'person', 'text': 'HERRN ABBÉ', 'page': 2},
#  '20': {'tag': 'person', 'text': 'D', 'page': 2},
#  '27': {'tag': 'work', 'text': 'Musikalische Syntaxis', 'page': 3},
#  '57': {'tag': 'work', 'text': 'Musikalische Syntaxis', 'page': 3},
#  '60': {'tag': 'work', 'text': 'Neue', 'page': 3},
#  '62': {'tag': 'work', 'text': 'Schule der Harmonik', 'page': 3},
#  '63': {'tag': 'work', 'text': 'Musikalische Grammatik', 'page': 3},
#  '103': {'tag': 'place', 'text': 'Bromberg', 'page': 4},
#  '104': {'tag': 'date', 'text': '1880', 'page': 4},
#  '106': {'tag': 'person', 'text': 'Dr. Hugo Riemann', 'page': 4},
#  '241': {'tag': 'musical_concept', 'text': 'Consonante Accorde', 'page': 8},
#  '244': {'tag': 'musical_concept', 'text': 'harmonische Bedeutung', 'page': 8},
#  '245': {'tag': 'musical_concept', 'text': 'Consonanz', 'page': 8},
#  '247': {'tag': 'musical_concept', 'text': 'Accorde', 'page': 8},
#  '249': {'tag': 'musical_concept', 'text': None, 'page': 8},
#  '255': {'tag': 'musical_concept', 'text': 'Stimmführung', 'page': 8},
#  '256': {'tag': 'musical_concept', 'text': 'Accordverbindung', 'page': 8},
#  '261': {'tag': 'musical_concept', 'text': 'Harmonieverkettungen', 'page': 8},
#  '263': {'tag': 'musical_concept', 'text': 'Klang', 'page': 8},
#  '266': {'tag': 'musical_concept', 'text': 'Klang', 'page': 8},
#  '269': {'tag': 'musical_concept', 'text': 'Accorde', 'page': 8},
#  '273': {'tag': 'musical_concept', 'text': 'Harmoniebedeutung', 'page': 8},
#  '275': {'tag': 'musical_concept', 'text': 'Klang', 'page': 8},
#  '277': {'tag': 'musical_concept', 'text': 'Tonbuchstaben', 'page': 8},
#  '279': {'tag': 'musical_concept', 'text': 'c-Duraccord', 'page': 8},
#  '281': {'tag': 'musical_concept', 'text': 'c-Mollaccord', 'page': 8},
#  '284': {'tag': 'musical_concept', 'text': 'Octavlagen', 'page': 8},
#  '287': {'tag': 'musical_concept', 'text': 'Tonbuchstaben', 'page': 8},
#  '288': {'tag': 'musical_concept', 'text': 'Ober¬', 'page': 8},
#  '290': {'tag': 'musical_concept', 'text': 'klang', 'page': 8},
#  '291': {'tag': 'musical_concept', 'text': 'Unterklang', 'page': 8},
#  '293': {'tag': 'musical_concept', 'text': 'Theoretiker', 'page': 8},
#  '296': {'tag': 'musical_concept', 'text': 'Oberklang', 'page': 8},
#  '298': {'tag': 'musical_concept', 'text': 'Unterklang', 'page': 8},
#  '299': {'tag': 'musical_concept', 'text': 'c', 'page': 8},
#  '301': {'tag': 'musical_concept', 'text': 'c-Oberklang', 'page': 8},
#  '303': {'tag': 'person', 'text': 'A. v. Öttingen', 'page': 8},
#  '304': {'tag': 'work',
#   'text': 'Harmoniesystem in dualer Entwickelung',
#   'page': 8},
#  '305': {'tag': 'date', 'text': '1866', 'page': 8},
#  '813': {'tag': 'musical_concept', 'text': 'Sopran', 'page': 15},
#  '970': {'tag': 'musical_concept', 'text': 'Terz', 'page': 17},
#  '971': {'tag': 'musical_concept', 'text': 'Klanges', 'page': 17},
#  '972': {'tag': 'musical_concept', 'text': 'Terz', 'page': 17},
#  '974': {'tag': 'musical_concept', 'text': 'Stimmenschritt', 'page': 17},
#  '1724': {'tag': 'unclear', 'text': None, 'page': 25},
#  '1745': {'tag': 'unclear', 'text': None, 'page': 25},
#  '2726': {'tag': 'unclear', 'text': 'Verminderter', 'page': 37},
#  '2727': {'tag': 'unclear', 'text': 'Dreiklang.', 'page': 37},
#  '2732': {'tag': 'unclear', 'text': 'Ton', 'page': 37},
#  '2733': {'tag': 'unclear', 'text': 'Dreiklang', 'page': 37},
#  '2735': {'tag': 'unclear', 'text': 'Mollaccord', 'page': 37},
#  '2736': {'tag': 'unclear', 'text': 'Ton', 'page': 37},
#  '2737': {'tag': 'unclear', 'text': 'Quintintervalls', 'page': 37},
#  '2739': {'tag': 'unclear', 'text': 'Oberton', 'page': 37},
#  '2741': {'tag': 'unclear', 'text': 'Septimenaccord', 'page': 37},
#  '2743': {'tag': 'unclear', 'text': 'Oberseptimenaccord', 'page': 37},
#  '2744': {'tag': 'unclear', 'text': 'Quinte,', 'page': 37},
#  '2745': {'tag': 'unclear', 'text': 'Unterseptimen¬', 'page': 37},
#  '2747': {'tag': 'unclear', 'text': 'accord', 'page': 37},
#  '2748': {'tag': 'unclear', 'text': 'Hauptton', 'page': 37},
#  '2750': {'tag': 'unclear', 'text': 'Ton', 'page': 37},
#  '2751': {'tag': 'unclear', 'text': 'Quintintervalls', 'page': 37},
#  '2752': {'tag': 'unclear', 'text': 'Dur', 'page': 37},
#  '2753': {'tag': 'unclear', 'text': 'Hauptton', 'page': 37},
#  '2755': {'tag': 'unclear', 'text': 'Moll', 'page': 37},
#  '2756': {'tag': 'unclear', 'text': 'Quinte)', 'page': 37},
#  '2757': {'tag': 'unclear', 'text': 'Basston', 'page': 37},
#  '2761': {'tag': 'unclear', 'text': 'Dreiklang', 'page': 37},
#  '2764': {'tag': 'unclear', 'text': 'Dreiklang', 'page': 37},
#  '2766': {'tag': 'unclear', 'text': 'Durseptimenaccord', 'page': 37},
#  '2768': {'tag': 'unclear', 'text': 'Dreiklang', 'page': 37},
#  '2769': {'tag': 'unclear', 'text': 'Tones,', 'page': 37},
#  '2771': {'tag': 'unclear', 'text': 'Haupttones,', 'page': 37},
#  '2772': {'tag': 'unclear', 'text': 'Dreiklang', 'page': 37},
#  '2774': {'tag': 'unclear', 'text': 'Dursinne', 'page': 37},
#  '2775': {'tag': 'unclear', 'text': 'Mollsinne', 'page': 37},
#  '2778': {'tag': 'unclear', 'text': None, 'page': 37},
#  '2780': {'tag': 'unclear', 'text': 'Hauptton', 'page': 37},
#  '2782': {'tag': 'unclear', 'text': 'Septimenaccord', 'page': 37},
#  '2784': {'tag': 'unclear', 'text': 'Moll', 'page': 37},
#  '2785': {'tag': 'unclear', 'text': 'VII', 'page': 37},
#  '2786': {'tag': 'unclear', 'text': 'Klangbuchstaben,', 'page': 37},
#  '2792': {'tag': 'unclear', 'text': 'Dreiklang', 'page': 37},
#  '2794': {'tag': 'unclear', 'text': 'Klangbuchstaben:', 'page': 37},
#  '2800': {'tag': 'unclear', 'text': 'Haupttones.', 'page': 37},
#  '2802': {'tag': 'unclear', 'text': 'Dreiklange', 'page': 37},
#  '2805': {'tag': 'unclear', 'text': 'dreitönige', 'page': 37},
#  '2806': {'tag': 'unclear', 'text': 'viertöni¬', 'page': 37},
#  '2808': {'tag': 'unclear', 'text': 'gen', 'page': 37},
#  '2810': {'tag': 'person', 'text': 'Richter', 'page': 37},
#  '2811': {'tag': 'unclear', 'text': 'Lehrbuches,', 'page': 37},
#  '2812': {'tag': 'unclear', 'text': 'Dreiklang', 'page': 37},
#  '2815': {'tag': 'unclear', 'text': 'Klangwirkung', 'page': 37},
#  '2817': {'tag': 'unclear', 'text': 'volle', 'page': 37},
#  '2818': {'tag': 'unclear', 'text': 'Septimenaccord', 'page': 37},
#  '2821': {'tag': 'unclear', 'text': 'Stim¬', 'page': 37},
#  '2824': {'tag': 'unclear', 'text': 'men', 'page': 37},
#  '2826': {'tag': 'unclear', 'text': 'Sequenzen', 'page': 37},
#  '2828': {'tag': 'unclear', 'text': 'dreistimmigen', 'page': 37},
#  '2829': {'tag': 'unclear', 'text': 'Satze', 'page': 37},
#  '2884': {'tag': 'complex_expression', 'text': '3. = dis', 'page': 39},
#  '2885': {'tag': 'complex_expression', 'text': "q'= ges)", 'page': 39},
#  '2893': {'tag': 'complex_expression',
#   'text': "ay= gis, q'6= ges",
#   'page': 39},
#  '3693': {'tag': 'musical_concept', 'text': 'Nonenaccorde', 'page': 48},
#  '3694': {'tag': 'musical_concept',
#   'text': 'Verminderter Septimenaccord',
#   'page': 48},
#  '3697': {'tag': 'musical_concept',
#   'text': 'verminderten Septimenaccorde',
#   'page': 48},
#  '3699': {'tag': 'musical_concept', 'text': 'Modulationen', 'page': 48},
#  '3700': {'tag': 'musical_concept', 'text': 'ver¬', 'page': 48},
#  '3702': {'tag': 'musical_concept',
#   'text': 'minderten Septimenaccord',
#   'page': 48},
#  '3703': {'tag': 'musical_concept', 'text': 'Klang', 'page': 48},
#  '3705': {'tag': 'musical_concept', 'text': 'Hauptton', 'page': 48},
#  '3706': {'tag': 'musical_concept', 'text': 'Accord', 'page': 48},
#  '3708': {'tag': 'musical_concept',
#   'text': 'harmonischen Unbestimmtheit',
#   'page': 48},
#  '3710': {'tag': 'musical_concept', 'text': 'temperirten System', 'page': 48},
#  '3711': {'tag': 'musical_concept', 'text': 'Klange', 'page': 48},
#  '3713': {'tag': 'musical_concept',
#   'text': 'verminderte Septimenaccorde',
#   'page': 48},
#  '3719': {'tag': 'musical_concept', 'text': 'Tonart', 'page': 48},
#  '3721': {'tag': 'musical_concept', 'text': 'Harmonik', 'page': 48},
#  '3723': {'tag': 'musical_concept', 'text': 'Accorden', 'page': 48},
#  '3724': {'tag': 'musical_concept', 'text': 'Tonart', 'page': 48},
#  '3726': {'tag': 'musical_concept',
#   'text': 'verminderten Septimen¬',
#   'page': 48},
#  '3728': {'tag': 'musical_concept', 'text': 'accorde', 'page': 48},
#  '3731': {'tag': 'musical_concept',
#   'text': 'verminderten Septimenaccorde',
#   'page': 48},
#  '3733': {'tag': 'musical_concept', 'text': 'Tonart', 'page': 48},
#  '4620': {'tag': 'musical_concept', 'text': 'Quartenvorhalt.', 'page': 63},
#  '4625': {'tag': 'musical_concept', 'text': 'Dissonanz', 'page': 63},
#  '4626': {'tag': 'musical_concept', 'text': 'Kleinterzwechsels:', 'page': 63},
#  '4631': {'tag': 'musical_concept', 'text': 'Dissonanz', 'page': 63},
#  '4632': {'tag': 'musical_concept', 'text': 'Tritonuswechsels', 'page': 63},
#  '4635': {'tag': 'musical_concept', 'text': 'vierstimmigen Satz', 'page': 63},
#  '4639': {'tag': 'musical_concept', 'text': 'Bezifferung', 'page': 63},
#  '4640': {'tag': 'musical_concept', 'text': 'Klänge', 'page': 63},
#  '4642': {'tag': 'unclear', 'text': 'theoretische Erklärung', 'page': 63},
#  '4644': {'tag': 'musical_concept', 'text': 'Accordbezifferung', 'page': 63},
#  '4646': {'tag': 'person', 'text': 'Gottfried Weber', 'page': 63},
#  '4647': {'tag': 'person', 'text': 'Richter', 'page': 63},
#  '4648': {'tag': 'musical_concept', 'text': 'General¬', 'page': 63},
#  '4650': {'tag': 'musical_concept', 'text': 'bassbezifferung', 'page': 63},
#  '4651': {'tag': 'unclear', 'text': 'praktischen Arbeiten', 'page': 63},
#  '4653': {'tag': 'musical_concept', 'text': 'Bezifferung', 'page': 63},
#  '4658': {'tag': 'unclear', 'text': 'Denkprozess', 'page': 63},
#  '4659': {'tag': 'musical_concept', 'text': 'Harmoniefolgen', 'page': 63},
#  '4664': {'tag': 'musical_concept', 'text': 'Disso¬', 'page': 63},
#  '4666': {'tag': 'musical_concept', 'text': 'nanzen', 'page': 63},
#  '4667': {'tag': 'musical_concept', 'text': 'Dur-', 'page': 63},
#  '4669': {'tag': 'musical_concept', 'text': 'Mollaccorde.', 'page': 63},
#  '4675': {'tag': 'musical_concept', 'text': None, 'page': 63},
#  '4680': {'tag': 'unclear', 'text': 'Gattung', 'page': 63},
#  '4682': {'tag': 'unclear', 'text': 'Klasse', 'page': 63},
#  '4689': {'tag': 'unclear', 'text': 'Fortschreitung', 'page': 63},
#  '6117': {'tag': 'person', 'text': 'Dr. ', 'page': 80},
#  '6119': {'tag': 'work', 'text': 'Die', 'page': 80},
#  '6121': {'tag': 'work',
#   'text': 'Lehre von den musikalischen Klängen',
#   'page': 80},
#  '7276': {'tag': 'musical_concept', 'text': 'Modulation', 'page': 93},
#  '7281': {'tag': 'musical_concept', 'text': 'unangenehme Wirkung', 'page': 93},
#  '7283': {'tag': 'musical_concept', 'text': 'Querstand', 'page': 93},
#  '7285': {'tag': 'musical_concept', 'text': 'Dissonanzen', 'page': 93},
#  '7286': {'tag': 'musical_concept', 'text': 'Tonika', 'page': 93},
#  '7288': {'tag': 'musical_concept', 'text': 'Vorhaltsdissonanzen', 'page': 93},
#  '7290': {'tag': 'musical_concept', 'text': 'Vorhalt', 'page': 93},
#  '7291': {'tag': 'musical_concept', 'text': 'accentuirt', 'page': 93},
#  '7292': {'tag': 'musical_concept', 'text': 'Auflösung', 'page': 93},
#  '7293': {'tag': 'musical_concept', 'text': 'accentlos', 'page': 93},
#  '7295': {'tag': 'musical_concept', 'text': 'accentuirt', 'page': 93},
#  '7296': {'tag': 'musical_concept', 'text': 'Auflösung', 'page': 93},
#  '7298': {'tag': 'musical_concept', 'text': 'Dissonanz', 'page': 93},
#  '7300': {'tag': 'musical_concept', 'text': 'accentuirt', 'page': 93},
#  '7302': {'tag': 'musical_concept',
#   'text': 'Durchgehende Dissonanzen',
#   'page': 93},
#  '7303': {'tag': 'musical_concept', 'text': 'stufen¬', 'page': 93},
#  '7305': {'tag': 'musical_concept',
#   'text': 'weise Fortschreitung',
#   'page': 93},
#  '7306': {'tag': 'musical_concept',
#   'text': 'liegenbleibende Töne',
#   'page': 93},
#  '7310': {'tag': 'musical_concept', 'text': 'accentlos', 'page': 93},
#  '7312': {'tag': 'musical_concept', 'text': 'Metrum', 'page': 93},
#  '7314': {'tag': 'musical_concept', 'text': 'Accent', 'page': 93},
#  '7315': {'tag': 'musical_concept', 'text': 'Modulation', 'page': 93},
#  '7318': {'tag': 'unclear', 'text': 'aversirt', 'page': 93},
#  '7319': {'tag': 'musical_concept', 'text': 'Accord', 'page': 93},
#  '7320': {'tag': 'musical_concept', 'text': 'Durchgangsbedeu¬', 'page': 93},
#  '7322': {'tag': 'musical_concept', 'text': 'tung', 'page': 93},
#  '7325': {'tag': 'musical_concept', 'text': 'Modulation', 'page': 93},
#  '7326': {'tag': 'musical_concept', 'text': 'Tonalität', 'page': 93},
#  '7328': {'tag': 'musical_concept', 'text': 'Tonikabedeutung', 'page': 93},
#  '7330': {'tag': 'musical_concept', 'text': 'Klang', 'page': 93},
#  '7332': {'tag': 'musical_concept', 'text': 'Kunstwerkes', 'page': 93},
#  '7333': {'tag': 'musical_concept', 'text': 'musikalischen', 'page': 93},
#  '7335': {'tag': 'musical_concept', 'text': 'Kunstwerke', 'page': 93},
#  '7336': {'tag': 'musical_concept', 'text': 'Tonart', 'page': 93},
#  '7339': {'tag': 'musical_concept', 'text': 'modulirt', 'page': 93},
#  '7340': {'tag': 'musical_concept', 'text': 'Künstlerschaft', 'page': 93},
#  '7342': {'tag': 'musical_concept', 'text': 'Haupttonart', 'page': 93},
#  '7345': {'tag': 'musical_concept', 'text': 'Kunstwerke', 'page': 93},
#  '7347': {'tag': 'musical_concept', 'text': 'Kunst', 'page': 93},
#  '7348': {'tag': 'musical_concept', 'text': 'Harmonik', 'page': 93},
#  '7350': {'tag': 'musical_concept', 'text': 'Tonalität', 'page': 93},
#  '7351': {'tag': 'musical_concept', 'text': 'Modulationen', 'page': 93},
#  '7353': {'tag': 'musical_concept', 'text': 'Haupttonart', 'page': 93},
#  '7355': {'tag': 'musical_concept', 'text': 'Tonart', 'page': 93},
#  '7358': {'tag': 'musical_concept', 'text': 'Nebentonart', 'page': 93},
#  '7465': {'tag': 'work', 'text': 'Die Hülfsmittel der Modulation', 'page': 95},
#  '7466': {'tag': 'place', 'text': 'Cassel,', 'page': 95},
#  '7467': {'tag': 'date', 'text': '1875', 'page': 95}}

# %%
name = path.split('.')[0]
ner_table = pandas.read_json(f'{name}_ner_tags.json', orient='index')

# %%
ner_table
# Out:
#       page              tag                            text
# 8        1           person                DR. HUGO RIEMANN
# 10       1            place                         LEIPZIG
# 12       1              org            BREITKOPF UND HÄRTEL
# 14       1             date                            1880
# 18       2           person                      HERRN ABBÉ
# 20       2           person                               D
# 27       3             work           Musikalische Syntaxis
# 57       3             work           Musikalische Syntaxis
# 60       3             work                            Neue
# 62       3             work             Schule der Harmonik
# 63       3             work          Musikalische Grammatik
# 103      4            place                        Bromberg
# 104      4             date                            1880
# 106      4           person                Dr. Hugo Riemann
# 241      8  musical_concept              Consonante Accorde
# 244      8  musical_concept           harmonische Bedeutung
# 245      8  musical_concept                       Consonanz
# 247      8  musical_concept                         Accorde
# 249      8  musical_concept                            None
# 255      8  musical_concept                    Stimmführung
# 256      8  musical_concept                Accordverbindung
# 261      8  musical_concept            Harmonieverkettungen
# 263      8  musical_concept                           Klang
# 266      8  musical_concept                           Klang
# 269      8  musical_concept                         Accorde
# 273      8  musical_concept               Harmoniebedeutung
# 275      8  musical_concept                           Klang
# 277      8  musical_concept                   Tonbuchstaben
# 279      8  musical_concept                     c-Duraccord
# 281      8  musical_concept                    c-Mollaccord
# ...    ...              ...                             ...
# 7310    93  musical_concept                       accentlos
# 7312    93  musical_concept                          Metrum
# 7314    93  musical_concept                          Accent
# 7315    93  musical_concept                      Modulation
# 7318    93          unclear                        aversirt
# 7319    93  musical_concept                          Accord
# 7320    93  musical_concept                Durchgangsbedeu¬
# 7322    93  musical_concept                            tung
# 7325    93  musical_concept                      Modulation
# 7326    93  musical_concept                       Tonalität
# 7328    93  musical_concept                 Tonikabedeutung
# 7330    93  musical_concept                           Klang
# 7332    93  musical_concept                     Kunstwerkes
# 7333    93  musical_concept                   musikalischen
# 7335    93  musical_concept                      Kunstwerke
# 7336    93  musical_concept                          Tonart
# 7339    93  musical_concept                        modulirt
# 7340    93  musical_concept                  Künstlerschaft
# 7342    93  musical_concept                     Haupttonart
# 7345    93  musical_concept                      Kunstwerke
# 7347    93  musical_concept                           Kunst
# 7348    93  musical_concept                        Harmonik
# 7350    93  musical_concept                       Tonalität
# 7351    93  musical_concept                    Modulationen
# 7353    93  musical_concept                     Haupttonart
# 7355    93  musical_concept                          Tonart
# 7358    93  musical_concept                     Nebentonart
# 7465    95             work  Die Hülfsmittel der Modulation
# 7466    95            place                         Cassel,
# 7467    95             date                            1875
#
# [205 rows x 3 columns]

# %%
ner_table.groupby(by='tag').count()
# Out:
#                     page  text
# tag
# complex_expression     3     3
# date                   4     4
# musical_concept      114   112
# org                    1     1
# person                 9     9
# place                  3     3
# unclear               62    59
# work                   9     9

# %% [markdown]
# ## Check types of nodes

# %%
counter.most_common()
# Out:
# [('lb', 6908),
#  ('hi', 292),
#  ('ab', 149),
#  ('musical_concept', 114),
#  ('pb', 98),
#  ('unclear', 62),
#  ('p', 47),
#  ('fw', 18),
#  ('rs', 13),
#  ('div', 9),
#  ('work', 9),
#  ('head', 8),
#  ('date', 4),
#  ('tone', 4),
#  ('note', 3),
#  ('complex_expression', 3),
#  ('comment', 2),
#  ('choice', 2),
#  ('corr', 2),
#  ('sic', 2),
#  ('blackening', 1)]

# %%
unknown = set(counter.keys())

unknown.difference_update(structure)
unknown.difference_update(useful)

print(unknown)
# Out:
# {'note', 'choice', 'fw', 'sic', 'corr', 'tone', 'blackening', 'comment'}
